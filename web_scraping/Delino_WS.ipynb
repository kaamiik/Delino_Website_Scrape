# %% [markdown]
# # Libraries

# %%
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import json
import pandas as pd
from collections import OrderedDict

# %% [markdown]
# # Scrape using APIs
# ### City Names
#
#
# <b>Extract city names and their keys in website. </b>

# %%
url          = "https://www.delino.com/init"
page         = requests.get(url)
j            = json.loads(page.text)
city_name_id = {}


for i in range (len(j['city'])):
    city_name_id[j['city'][i]['id']] = j['city'][i]['text']
    
    
city_name = list(city_name_id.values())
city_id   = list(city_name_id.keys())

city_name.remove("بوکان") # No records for Bukan
city_id.remove(1036)
city_name_id
# Out:
# {1: 'تهران',
#  1003: 'قم',
#  1005: 'بندرعباس',
#  1007: 'کرج',
#  1008: 'رشت',
#  1009: 'گرگان',
#  1011: 'همدان',
#  1012: 'یزد',
#  1013: 'ارومیه',
#  1015: 'گنبد کاووس',
#  1033: 'اراک',
#  1036: 'بوکان'}

# %% [markdown]
# # Scrape using APIs
# ### Food Tags
#
#
# <b>Extract food tags and their keys in website. </b>

# %%
url          = "https://www.delino.com/init"
page         = requests.get(url)
j            = json.loads(page.text)
food_text_id = {}
for i in range(len(j['foodTagList'])):
    food_text_id[j['foodTagList'][i]['id']] = [j['foodTagList'][i]['text'], j['foodTagList'][i]['tag']]
    
text_id   = list(food_text_id.keys())
food_text = list(food_text_id.values())
food_text_id
# Out:
# {1: ['غذای مقرون به صرفه', 'economic'],
#  2: ['غذای تند', 'chili'],
#  3: ['غذای سلامت', 'healthy'],
#  5: ['غذای رژیمی', 'diet'],
#  6: ['غذای دریایی', 'seafood'],
#  8: ['غذای بین المللی', 'international'],
#  9: ['غذای محلی', 'local'],
#  10: ['صبحانه', 'breakfast'],
#  11: ['غذای کودک', 'kids'],
#  13: ['Vegan (فاقد لبنیات)', 'Vegan'],
#  14: ['حاوی نوتلا', 'Nutella included!'],
#  15: ['فاقد قند', 'No sugar'],
#  16: ['حاوی کافئین (اسپرسو یا نسکافه)', 'Caffeinated'],
#  17: ['کتوژنیک', 'Ketogenic'],
#  18: ['ماست بستنی', 'Frozen Yogurt'],
#  19: ['انرژی زا', 'Energizer'],
#  21: ['کباب ها', 'Kabab'],
#  25: ['غذای اصلی', 'main food'],
#  26: ['غذای ملل', 'food melal'],
#  27: ['دسر', 'deser'],
#  29: ['سوپ وسالادها', 'apllitizer'],
#  30: ['صبحانه', 'Berakfast'],
#  31: ['فست فود', 'Fast Food'],
#  32: ['شیرینی تر', 'wet sweet'],
#  33: ['شیرینی خشک', 'dry sweet'],
#  34: ['کیک', 'cake'],
#  35: ['کیک سفارشی', 'custom special cake'],
#  36: ['برگر', '????'],
#  37: ['بدون سوسیس', '???? ?????'],
#  38: ['پیتزا', '?????'],
#  39: ['شکلاتی!', 'Chocolate'],
#  40: ['پیتزا بدون قارچ', '????? ???? ????'],
#  41: ['پیتزا تند', '????? ???'],
#  42: ['حاوی Bubble', 'Bubbles'],
#  43: ['گیاهخواران', 'vegetable'],
#  45: ['وگان Vegan', 'Vegan'],
#  46: ['خام گیاهخواری', 'Raw vegan'],
#  47: ['INDIAN', 'INDIAN'],
#  48: ['ASIAN', 'ASIAN'],
#  50: ['خانواده Alps', 'On Alps'],
#  51: ['ITALIAN', 'ITALIAN'],
#  53: ['خانواده Fresco', 'Fresco']}

# %% [markdown]
# # Scrape using APIs
# ### Food Category
#
#
# <b>Extract food category and their keys in website. </b>

# %%
url         = "https://www.delino.com/init"
page        = requests.get(url)
j           = json.loads(page.text)
food_cat_id = {}
for i in range(len(j['foodCategoryList'])):
    food_cat_id[j['foodCategoryList'][i]['id']] = j['foodCategoryList'][i]['text']
    
cat_id   = list(food_cat_id.keys())
food_cat = list(food_cat_id.values())
food_cat_id
# Out:
# {1: 'پیتزا',
#  2: 'کباب',
#  18154: 'سوپ',
#  7: 'ساندویچ',
#  3: 'غذای ایرانی',
#  4: 'سوخاری',
#  9: 'پاستا',
#  8838: 'سالاد',
#  4650: 'صبحانه',
#  8: 'استیک'}

# %% [markdown]
# # Scrape using APIs
# ### Areas
#
#
# <b>Extract Areas in each city and their keys in website. </b>

# %%
url          = "https://www.delino.com/init"
page         = requests.get(url)
j            = json.loads(page.text)
area_lat_lng = {}
city         = j['city']

for i in range(len(city)-1):
    city_zone = city[i]['zone']
    
    for j in range(len(city_zone)):
        city_zone_area = city_zone[j]['area']
        
        for k in range(len(city_zone_area)):
            
            if city_zone_area[k]['text'] != None:
                
                area_lat_lng[city_zone_area[k]['text']] = [round(city_zone_area[k]['lat'],6), round(city_zone_area[k]['lng'],6)]

area    = list(area_lat_lng.keys())
lat_lng = list(area_lat_lng.values())
area_lat_lng
# Out:
# {'110': [35.741645, 51.003857],
#  '30متری اسلام آباد': [36.544042, 46.21974],
#  'آجودانیه': [35.805894, 51.487985],
#  'آزادگان': [37.244465, 55.18438],
#  'آصف': [35.81007, 51.411542],
#  'آقا بزرگی': [35.795121, 51.425468],
#  'اتوبان ارتش': [35.79714, 51.509142],
#  'ادب جنوبی': [36.482337, 46.210363],
#  'ادب شمالی': [36.486512, 46.210041],
#  'اراج': [35.799507, 51.487684],
#  'ازگل': [35.78976, 51.512146],
#  'استاد بی که س': [36.511028, 46.202896],
#  'استاد ترجانی زاده': [36.504574, 46.200213],
#  'استاد حقیقی': [36.526464, 46.211264],
#  'استاد هیمن': [36.520783, 46.204011],
#  'اقدسیه': [35.793694, 51.48747],
#  'الهیه': [34.104577, 49.743285],
#  'امامزاده قاسم': [35.815516, 51.433096],
#  'اندرزگو': [35.801525, 51.453867],
#  'انستیتو پاستور': [35.691078, 51.396618],
#  'انقلاب': [31.901948, 54.356888],
#  'اوشان': [35.820214, 51.478329],
#  'اوین': [35.794947, 51.392241],
#  'بابان': [36.521455, 46.21709],
#  'باغ فردوس': [35.800464, 51.423569],
#  'بام تهران': [35.815777, 51.409428],
#  'باهنر (نیاوران)': [35.812497, 51.456388],
#  'بزرگراه چایکنار': [38.081811, 46.293468],
#  'بعثت': [34.1233, 49.69316],
#  'بلوار آزادی': [35.846736, 50.925558],
#  'بلوار ابوذر غفاری': [29.566533, 52.555633],
#  'بلوار استاد هژار': [36.495945, 46.2059],
#  'بلوار امام خمینی': [36.540318, 46.211758],
#  'بلوار امیرکبیر': [35.756006, 50.897276],
#  'بلوار بسیج': [35.766443, 50.915129],
#  'بلوار پاسداران': [32.869861, 59.221637],
#  'بلوار جمهوری اسلامی': [36.531992, 46.212012],
#  'بلوار دانش': [35.808214, 50.91249],
#  'بلوار دانشجو': [35.801786, 51.395481],
#  'بلوار دانشگاه': [36.551026, 46.216179],
#  'بلوار دکتر شریعتی': [29.682404, 52.464094],
#  'بلوار ساحلی': [36.52629, 46.202353],
#  'بلوار سربازان گمنام': [36.530607, 46.208347],
#  'بلوار سیمینه': [36.498759, 46.20193],
#  'بلوار شهدا': [37.567562, 45.063558],
#  'بلوار شهرزاد': [35.766677, 51.449339],
#  'بلوار منصوری': [36.510177, 46.210985],
#  'بلوار کاوه': [35.786192, 51.445713],
#  'بلوار کردستان': [36.511017, 46.207646],
#  'بهرامی': [36.5183, 46.204046],
#  'بوکان': [35.816995, 51.442623],
#  'بیمارستان دکتر قلی پور': [36.524341, 46.226585],
#  'پارک قیطریه': [35.793119, 51.448996],
#  'پارک نیاوران': [35.808486, 51.471462],
#  'پاسداران': [37.237891, 55.170507],
#  'پاسداران چهارراه تا نوبنیاد': [35.785896, 51.470304],
#  'پاسداران نوبنیاد': [35.788542, 51.474831],
#  'پسیان': [35.802535, 51.415758],
#  'پور ابتهاج': [35.816769, 51.482803],
#  'تست': [35.491058, 51.829376],
#  'جانبازان': [37.541386, 45.074906],
#  'جماران': [37.251639, 49.59029],
#  'جمال آباد': [35.816526, 51.474552],
#  'جمشیدیه': [35.824059, 51.463587],
#  'چناران': [35.779597, 50.895259],
#  'چنچنه': [29.638045, 52.533617],
#  'چهارراه فرمانیه': [35.798906, 51.474735],
#  'چیذر': [35.796826, 51.455498],
#  'چیمن': [36.540698, 46.21532],
#  'حاج ابوبکر آقا': [36.521766, 46.221038],
#  'حضرت حمزه': [36.501141, 46.202681],
#  'حلبچه': [36.533103, 46.207455],
#  'حکمت': [35.801003, 51.443782],
#  'خزر': [35.78862, 51.433815],
#  'خیابان دانشگاه': [34.098663, 49.708691],
#  'خیابان زیتون': [36.494569, 46.201984],
#  'خیابان شهرداری تجریش': [35.805606, 51.431991],
#  'خیابان مریوان': [36.543456, 46.216693],
#  'دارآباد': [35.81529, 51.490431],
#  'دربند': [35.815934, 51.425457],
#  'درکه': [35.802639, 51.38546],
#  'دزاشیب': [35.807094, 51.452923],
#  'دکتر حسابی': [34.086811, 49.698405],
#  'دیمن': [36.539698, 46.218882],
#  'دیمه ن': [36.535643, 46.216599],
#  'رز': [36.514825, 46.215405],
#  'رودبار': [36.497225, 46.197488],
#  'روشنایی': [35.789777, 51.448352],
#  'زانا': [36.529978, 46.217507],
#  'زعفرانیه': [35.805911, 51.414385],
#  'زند': [29.620587, 52.531643],
#  'سالمندان': [36.50809, 46.201737],
#  'ستارخان': [29.62663, 52.499027],
#  'سردار عزیزخان موکری': [36.534058, 46.213301],
#  'سعدآباد': [35.811827, 51.419878],
#  'سه راه اقدسیه': [35.805615, 51.472342],
#  'سه راه یاسر': [35.812758, 51.451185],
#  'سهیل': [35.787906, 51.439962],
#  'سوهانک': [35.802048, 51.533518],
#  'شاخه وان': [36.537939, 46.213287],
#  'شاه چراغ': [29.608685, 52.547264],
#  'شریعتی الهیه': [35.798428, 51.433654],
#  'شریعتی قیطریه': [35.791779, 51.43507],
#  'شهرک البرز': [35.806537, 51.505752],
#  'شهرک چمران': [35.793728, 51.479058],
#  'شهرک حمید': [34.127038, 49.704037],
#  'شهرک صدف': [35.691485, 51.038704],
#  'شهرک قائم': [34.117487, 49.692986],
#  'شهرک گلها': [35.804005, 51.498188],
#  'شهرک محلاتی': [35.802152, 51.510129],
#  'شهرک نفت': [35.809574, 51.504185],
#  'شهرک ولیعصر': [37.541588, 45.005902],
#  'شهید باهنر': [36.517694, 46.202102],
#  'شهید بهشتی': [34.668609, 50.88099],
#  'شهید ذوالفقاری': [36.526169, 46.205185],
#  'شهید رجایی': [34.082644, 49.694295],
#  'شهید عباسی': [36.528146, 46.208764],
#  'شورا': [36.491646, 46.207638],
#  'شیلان': [36.506425, 46.204024],
#  'صاحبقرانیه': [35.808347, 51.475067],
#  'عدالت': [35.817597, 50.900506],
#  'فخر آباد': [29.610887, 52.524004],
#  'فرشته': [35.789238, 51.422024],
#  'فرگاز': [29.58066, 52.501259],
#  'فرمانیه شرقی': [35.800272, 51.481719],
#  'فرمانیه غربی': [35.800272, 51.466227],
#  'فرهنگیان': [37.256207, 55.190871],
#  'فلکه قدس': [36.514825, 46.213839],
#  'قانع': [36.536258, 46.205921],
#  'قلندری شمالی': [35.789925, 51.442494],
#  'قیطریه': [35.791849, 51.443825],
#  'گلابدره': [35.82011, 51.435757],
#  'گوران شمالی': [36.532306, 46.215361],
#  'لاچین': [36.521265, 46.201979],
#  'لواسان': [35.820076, 51.625292],
#  'مانا': [36.532903, 46.216905],
#  'مجتمع مسکونی سبحان': [35.790565, 51.443739],
#  'محمودیه': [35.795121, 51.413698],
#  'مطهری': [36.509259, 46.212426],
#  'مقبل هنر پژوه': [36.512442, 46.204505],
#  'مقدس اردبیلی': [35.797035, 51.406918],
#  'مقصود بیک': [35.80424, 51.427259],
#  'منظریه': [37.262561, 49.593959],
#  'مولوی شرقی': [36.521334, 46.210696],
#  'میدان  سعدی': [37.513379, 45.048119],
#  'میدان اراج': [35.801726, 51.486847],
#  'میدان اسکندری': [36.522938, 46.206908],
#  'میدان الف': [35.797662, 51.412035],
#  'میدان امام': [34.069778, 49.659736],
#  'میدان امام خمینی(آزادگان)': [36.53593, 46.210095],
#  'میدان تجریش': [35.807025, 51.428633],
#  'میدان دارآباد': [35.818257, 51.491375],
#  'میدان فرمانداری': [36.514868, 46.207348],
#  'میدان قدس': [35.804823, 51.434158],
#  'میدان معلم': [36.500182, 46.206385],
#  'میدان ندا': [35.797636, 51.456506],
#  'میدان نوبنیاد': [35.791414, 51.477878],
#  'میدان نیاوران': [35.810931, 51.470153],
#  'میرزای شیرازی': [34.081127, 49.67876],
#  'مینی سیتی': [35.79164, 51.505623],
#  'نالیشکینه': [36.499483, 46.210116],
#  'نواب صفوی': [35.681562, 51.378937],
#  'نیاوران': [35.811932, 51.46142],
#  'نیاوران قدس': [35.809043, 51.443224],
#  'هاشمی': [36.516584, 46.216854],
#  'وحدت': [34.810804, 48.535746],
#  'وفایی': [36.497827, 46.209456],
#  'ولنجک': [35.805981, 51.401081],
#  'ولیعصر فرشته': [35.792754, 51.416574],
#  'ولیعصر محمودیه': [35.798184, 51.417947],
#  'کاخ سعدآباد': [35.816352, 51.419964],
#  'کاخ نیاوران': [35.812141, 51.472224],
#  'کاشانک': [35.808974, 51.481118],
#  'کامرانیه جنوبی': [35.797279, 51.460605],
#  'کامرانیه شمالی': [35.806468, 51.462407],
#  'کوهسار ولنجک': [35.812393, 51.392916],
#  'کوی دانشگاه تهران': [35.730837, 51.387348],
#  'کوی لاله': [35.796583, 51.534119],
#  'یافت آباد جنوبی': [35.644575, 51.30568],
#  'یوسف': [36.52011, 46.219128],
#  'آتی ساز': [35.785165, 51.390996],
#  'آزادی - توحید': [35.700854, 51.37795],
#  'اکبری (مستوفی)': [35.737456, 51.407819],
#  'ایثار': [35.731708, 51.351256],
#  'ایران زمین': [35.757762, 51.379924],
#  'ایوانک': [35.759607, 51.35499],
#  'باقرخان': [35.710542, 51.376791],
#  'برج میلاد': [35.744701, 51.375246],
#  'برق آلستوم': [35.723312, 51.352737],
#  'بلوار آریافر': [35.730489, 51.355805],
#  'بلوار درختی': [35.768835, 51.354303],
#  'بلوار دریا': [35.77176, 51.370053],
#  'بلوار دلاوران': [35.745816, 51.509271],
#  'بلوار شهرداری جنوبی': [35.777262, 51.368551],
#  'بلوار شهرداری شمالی': [35.785234, 51.366491],
#  'بلوار صالحی': [35.70683, 51.345323],
#  'بلوار فرهنگ سعادت آباد': [35.77848, 51.385288],
#  'بلوار مدیریت': [35.770925, 51.380847],
#  'بلوار کوهسار': [35.747836, 51.28581],
#  'بلوار کوهستان': [35.776391, 51.350398],
#  'بهبودی': [35.706552, 51.368122],
#  'بیست و چهار متری (سعادت آباد)': [35.776739, 51.381512],
#  'پاتریس لومومبا': [35.719688, 51.374173],
#  'پارک گفتگو': [35.737909, 51.381469],
#  'پاکنژاد بالاتر از دریا': [35.77284, 51.363788],
#  'پاکنژاد پایین تر از دریا': [35.762045, 51.367435],
#  'پل مدیریت': [35.770925, 51.387337],
#  'پل نصر (گیشا)': [35.726047, 51.378937],
#  'تهران نو': [35.708747, 51.497254],
#  'تهران ویلا': [35.721483, 51.365569],
#  'تیموری': [35.70568, 51.354218],
#  'جلال آل احمد': [35.728747, 51.369581],
#  'چهارراه سرو': [35.778776, 51.362307],
#  'چهارراه مسجد': [35.770933, 51.378368],
#  'چوب تراش': [35.715376, 51.344326],
#  'حبیب الله': [35.713904, 51.358938],
#  'خوردین': [35.759433, 51.374044],
#  'خیابان خسرو': [35.720873, 51.346922],
#  'دادمان': [35.765998, 51.361384],
#  'دانشگاه شریف': [35.703572, 51.350741],
#  'زرافشان': [35.761923, 51.356814],
#  'ستارخان از اشرفی تا شیخ فضل الله': [35.721639, 51.349111],
#  'ستارخان از شیخ فضل الله تا پاتریس': [35.717284, 51.365376],
#  'ستارخان توحید': [35.708085, 51.374817],
#  'ستارخان نیایش': [35.717406, 51.366792],
#  'سرو شرقی': [35.782902, 51.379677],
#  'سرو غربی': [35.781126, 51.371534],
#  'سعادت آباد': [35.785753, 51.380618],
#  'سعادت آباد بالاتر از میدان کاج': [35.785461, 51.373701],
#  'سعادت آباد پایین تر از میدان کاج': [35.776809, 51.376576],
#  'شادمهر': [35.708538, 51.365676],
#  'شهرآرا': [35.720664, 51.370912],
#  'شهرک آزمایش': [35.733367, 51.369761],
#  'شهرک بوعلی': [35.793624, 51.36117],
#  'شهرک ژاندارمری': [35.731673, 51.360977],
#  'شهرک غرب': [35.760791, 51.372542],
#  'شهرک مخابرات': [35.793206, 51.358198],
#  'شهرک هما': [35.747905, 51.336622],
#  'طرشت': [35.70683, 51.347737],
#  'علامه طباطبایی جنوبی': [35.774546, 51.382327],
#  'علامه طباطبایی شمالی': [35.780534, 51.380267],
#  'فرحزادی بالاتر از دادمان': [35.774058, 51.357565],
#  'فرحزادی پایین تر دادمان': [35.759642, 51.361814],
#  'فلامک جنوبی': [35.753304, 51.359239],
#  'فلامک شمالی': [35.76013, 51.358423],
#  'فلکه اول صادقیه': [35.72184, 51.340892],
#  'فلکه دوم صادقیه': [35.722136, 51.335206],
#  'گل افشان (شهرک غرب)': [35.760234, 51.346149],
#  'گیشا  (نصر)': [35.726047, 51.378937],
#  'مجتمع مسکونی سروستان': [35.782911, 51.360279],
#  'مرزداران': [35.734634, 51.348853],
#  'میدان بهرود': [35.791296, 51.358064],
#  'میدان توحید': [35.811101, 50.999308],
#  'میدان تیموری': [35.707292, 51.351122],
#  'میدان شهرداری (قیصر امین پور)': [35.780273, 51.367875],
#  'میدان صنعت (شهرک غرب)': [35.754148, 51.368229],
#  'میدان فرهنگ (سعادت آباد)': [35.78372, 51.384526],
#  'میدان کاج': [35.781927, 51.374913],
#  'میدان کتاب': [35.777305, 51.355816],
#  'نصرت غربی': [35.705437, 51.372607],
#  'هتل اوین': [35.788994, 51.390696],
#  'هرمزان': [35.762707, 51.370268],
#  'ویلا (نجات الهی)': [35.715193, 51.414514],
#  'کوی فراز': [35.789673, 51.370697],
#  'کوی نصر': [35.736184, 51.376534],
#  'آرارات': [35.767948, 51.400459],
#  'آرش شرقی': [35.768949, 51.429877],
#  'آرش غربی': [35.770359, 51.422367],
#  'آفریقا از ظفر تا میرداماد (جردن)': [35.765406, 51.419234],
#  'آفریقا بالاتر از ظفر (جردن)': [35.777227, 51.42211],
#  'آفریقا پایین تر از میرداماد (جردن)': [35.759712, 51.414428],
#  'احتشامیه': [35.7766, 51.457343],
#  'اختیاریه جنوبی': [35.776565, 51.463737],
#  'اختیاریه شمالی': [35.783807, 51.464295],
#  'ارسباران': [35.744213, 51.443878],
#  'اسفندیار': [35.771029, 51.416874],
#  'اسکان': [35.763717, 51.41108],
#  'برزیل': [35.755254, 51.407261],
#  'بهروز': [35.760722, 51.44228],
#  'پارک آب و آتش': [35.754349, 51.418591],
#  'پارک طالقانی': [35.754227, 51.42271],
#  'پارک ملت': [35.777505, 51.410007],
#  'پارک وی': [35.790891, 51.416101],
#  'پاسداران بوستان': [35.765092, 51.455841],
#  'پاسداران ضرابخانه': [35.775765, 51.471548],
#  'پاسداران گلستان': [35.771377, 51.465111],
#  'پاسداران نگارستان': [35.757797, 51.454296],
#  'پل رومی': [35.783459, 51.436057],
#  'جلفا': [35.74801, 51.443911],
#  'چهارراه پاسداران': [35.781405, 51.468222],
#  'چهارراه جهان کودک': [35.757797, 51.414374],
#  'چهارراه قنات': [35.780369, 51.453803],
#  'چهارراه کاوه': [35.779864, 51.449511],
#  'حسینیه ارشاد': [35.756926, 51.447816],
#  'خدامی': [35.762951, 51.4043],
#  'خیابان آفتاب': [35.766154, 51.398592],
#  'خیابان امیرنیا': [35.753565, 51.472642],
#  'خیابان عطار': [35.762659, 51.407368],
#  'خیابان ونک': [35.759555, 51.40666],
#  'درب دوم': [35.782554, 51.436143],
#  'دروس': [35.772248, 51.454897],
#  'ده ونک': [35.766572, 51.391726],
#  'دو راهی قلهک': [35.773997, 51.43728],
#  'دولت(کلاهدوز)': [35.779977, 51.456313],
#  'دیباجی جنوبی': [35.787132, 51.459875],
#  'دیباجی شمالی': [35.796409, 51.466012],
#  'زرگنده (خاقانی)': [35.777827, 51.436132],
#  'سئول': [35.770855, 51.396918],
#  'سئول چمران': [35.789847, 51.392455],
#  'سئول نیایش': [35.774685, 51.395459],
#  'سه راه ضرابخانه': [35.752189, 51.448975],
#  'سه راه نشاط': [35.779063, 51.444694],
#  'سیدخندان': [35.741949, 51.446829],
#  'شریعتی دولت': [35.775529, 51.436551],
#  'شریعتی سهیل': [35.788881, 51.435724],
#  'شریعتی صدر': [35.784138, 51.436046],
#  'شریعتی ظفر': [35.765667, 51.442623],
#  'شریعتی میرداماد': [35.760165, 51.445799],
#  'شریعتی همت': [35.752921, 51.448803],
#  'شمس تبریزی': [35.760051, 51.431562],
#  'شهرک سئول': [35.777418, 51.393635],
#  'شهرک فجر': [35.774616, 51.400695],
#  'شهرک نور': [35.774955, 51.399268],
#  'شیخ بهایی جنوبی': [35.745711, 51.397133],
#  'شیخ بهایی شمالی': [35.760443, 51.395888],
#  'شیراز جنوبی': [35.753861, 51.400738],
#  'شیراز شمالی': [35.759747, 51.400008],
#  'ظفر(دستگردی)': [35.766119, 51.431894],
#  'فرید افشار': [35.769097, 51.427667],
#  'قبا': [35.76114, 51.44964],
#  'قلندری جنوبی': [35.78298, 51.439984],
#  'قلهک': [35.77277, 51.443267],
#  'گاندی شمالی': [35.758493, 51.411767],
#  'گل نبی': [35.756604, 51.450691],
#  'مجموعه ورزشی انقلاب': [35.781683, 51.39812],
#  'ملاصدرا': [35.756752, 51.398892],
#  'میدان احتشامیه': [35.768418, 51.454892],
#  'میدان اختیاریه': [35.786914, 51.466559],
#  'میدان جوانان': [35.753896, 51.445992],
#  'میدان شیخ بهایی': [35.765789, 51.395202],
#  'میدان مادر (محسنی)': [35.758519, 51.442806],
#  'میدان مینا': [35.762559, 51.441996],
#  'میدان هدایت': [35.775939, 51.4506],
#  'میدان ونک': [35.757544, 51.409986],
#  'میدان کتابی(احمد روشن)': [35.751654, 51.444141],
#  'میرداماد': [35.761836, 51.420264],
#  'میرداماد از شریعتی تا مدرس': [35.759816, 51.433868],
#  'میرداماد از مدرس تا ولیعصر': [35.762533, 51.415286],
#  'نفت شمالی': [35.763543, 51.428847],
#  'نمایشگاه تهران': [35.786697, 51.405115],
#  'هدایت': [35.770281, 51.448073],
#  'والی نژاد': [35.760778, 51.41151],
#  'ولیعصر جام جم': [35.780778, 51.414084],
#  'ولیعصر ظفر': [35.769044, 51.411552],
#  'ولیعصر میرداماد': [35.763125, 51.410351],
#  'ولیعصر نیایش': [35.771604, 51.41211],
#  'ونک سئول': [35.767408, 51.396253],
#  'یخچال': [35.771961, 51.441228],
#  'آیت بالاتر از رسالت': [35.73763, 51.495237],
#  'اردیبهشت جنوبی': [35.740974, 51.519313],
#  'اردیبهشت شمالی': [35.74902, 51.524291],
#  'استخر': [35.755498, 51.559782],
#  'باغ لویزان': [35.784582, 51.496031],
#  'برادران پناهی نیا': [35.762219, 51.474638],
#  'بلوار استقلال': [35.757309, 51.542873],
#  'بلوار پروین': [35.727423, 51.530621],
#  'بلوار جشنواره': [35.730628, 51.546478],
#  'بلوار شاهد': [34.794409, 48.536819],
#  'بنی هاشم': [37.548037, 45.091066],
#  'بنیاد': [34.531904, 50.899057],
#  'پارک جنگلی شهید فلاحی': [35.780291, 51.499786],
#  'پارک جنگلی لویزان': [35.765806, 51.506567],
#  'پایدارفرد': [35.759059, 51.464413],
#  'تهران پارس': [35.727667, 51.522875],
#  'چهارراه سراج': [35.744753, 51.516995],
#  'حکیمیه': [35.73871, 51.583729],
#  'خواجه عبدالله انصاری': [35.744492, 51.455154],
#  'خیابان الغدیر': [35.743273, 51.508241],
#  'ساقدوش (افشاری)': [35.763473, 51.470003],
#  'سراج': [35.748341, 51.518433],
#  'شعبانلو': [35.781335, 51.495366],
#  'شهرک امید': [37.52512, 45.106537],
#  'شهید عراقی': [35.750448, 51.461291],
#  'شیان': [35.772666, 51.49498],
#  'فرجام': [35.737943, 51.506224],
#  'فرخی یزدی': [35.759259, 51.458437],
#  'لویزان': [35.763995, 51.494808],
#  'مجدیه شمالی': [35.744771, 51.469188],
#  'مجیدیه شمالی': [35.761732, 51.480045],
#  'مریم': [35.786435, 51.425092],
#  'ملت': [35.687461, 51.426519],
#  'مهران': [35.749786, 51.454983],
#  'مکران': [35.765527, 51.473565],
#  'میدان اشراق': [35.732013, 51.545263],
#  'میدان پروین': [35.742002, 51.542358],
#  'میدان تختی': [35.743752, 51.561853],
#  'میدان رسالت': [35.736724, 51.487985],
#  'میدان قنات کوثر': [35.759042, 51.532048],
#  'میدان ملت': [35.754832, 51.476972],
#  'میدان هروی': [35.767251, 51.476333],
#  'هتل شیان': [35.764866, 51.496224],
#  'هروی-چهار راه مژده': [35.777993, 51.481354],
#  'هنگام': [35.742803, 51.495473],
#  'وفامنش': [35.772596, 51.477427],
#  'آبشناسان': [35.769567, 51.328082],
#  'آیت الله کاشانی': [35.727284, 51.320229],
#  'ابوذر - اشرفی اصفهانی': [35.730349, 51.3304],
#  'اشرفی اصفهانی بالاتر از نیایش': [35.773066, 51.336622],
#  'اشرفی اصفهانی تیراژه': [35.74808, 51.331794],
#  'باغ فیض': [35.746025, 51.323576],
#  'بزرگراه جناح': [35.710559, 51.336451],
#  'بلوار باهنر ستاری': [35.741775, 51.322589],
#  'بلوار عدل': [35.765423, 51.331944],
#  'بلوار فردوس شرقی': [35.723704, 51.315787],
#  'بلوار فردوس غرب': [35.727506, 51.303191],
#  'بلوار فردوس غربی': [35.729687, 51.297526],
#  'پونک شمالی': [35.76539, 51.329678],
#  'پیامبر شرقی': [35.736637, 51.327546],
#  'پیامبر غربی': [35.738309, 51.310315],
#  'پیامبر مرکزی': [35.737613, 51.316903],
#  'جنت آباد جنوبی': [35.743726, 51.303921],
#  'جنت آباد شمالی': [35.771691, 51.306925],
#  'جنت آباد مرکزی': [35.759468, 51.303835],
#  'چهار دیواری': [35.778411, 51.335807],
#  'حصارک': [35.781683, 51.30744],
#  'دخانیات': [36.810091, 54.452516],
#  'زیتون': [35.77573, 51.327181],
#  'سازمان آب': [35.74336, 51.290553],
#  'سازمان آب آیت الله کاشانی': [35.742611, 51.290917],
#  'سازمان برنامه': [35.736306, 51.300831],
#  'ستاری حکیم': [35.734565, 51.312032],
#  'سردار جنگل': [35.761279, 51.325207],
#  'سیمون بولیوار': [35.77855, 51.328855],
#  'شاهین جنوبی': [35.748916, 51.310487],
#  'شاهین شمالی': [35.762184, 51.310787],
#  'شهر زیبا': [35.748811, 51.292334],
#  'شهران': [35.768348, 51.291432],
#  'شهرک آپادانا': [35.711361, 51.324821],
#  'شهرک شرکت نفت (OPG)': [35.770785, 51.283493],
#  'شهرک نفت سیمون بولیوار': [35.787184, 51.337738],
#  'شهرک والفجر': [35.641324, 51.500559],
#  'فاز دو اکباتان': [35.707702, 51.306195],
#  'فاز یک اکباتان': [35.704182, 51.312976],
#  'فلکه اول شهران': [35.762829, 51.289995],
#  'فلکه دوم شهران': [35.765789, 51.288579],
#  'گلفام': [35.756839, 51.241672],
#  'مجتمع تجاری کورش': [35.738588, 51.314242],
#  'مراد آباد': [35.784016, 51.3304],
#  'میدان پونک': [35.759947, 51.33504],
#  'میدان دانشگاه علوم تحقیقات': [35.777854, 51.32025],
#  'کن': [35.760234, 51.276712],
#  'کوی ارم': [35.724357, 51.291819],
#  'کوی بیمه': [35.703694, 51.320014],
#  'آ اس پ': [35.744544, 51.399332],
#  'آبان جنوبی (شهید عضدی)': [35.711622, 51.412733],
#  'آبان شمالی (شهید عضدی)': [35.719079, 51.413677],
#  'آفریقا همت تا آرژانتین (جردن)': [35.746686, 51.415586],
#  'اعتمادزاده': [35.716856, 51.3834],
#  'الوند': [35.741401, 51.413988],
#  'امیرآباد جنوبی': [35.736483, 51.391347],
#  'امیرآباد شمالی': [35.739267, 51.391468],
#  'ایرانشهر': [35.708852, 51.422753],
#  'بخارست (احمد قصیر)': [35.732561, 51.416917],
#  'برادران مظفر': [35.706582, 51.405067],
#  'برج تهران': [35.742711, 51.398946],
#  'بزرگراه مدرس': [35.756821, 51.420318],
#  'بزرگمهر': [35.703581, 51.401596],
#  'بلوار کشاورز': [34.654851, 50.844898],
#  'بلوار کشاورز - حجاب': [35.708982, 51.397079],
#  'بلوار کشاورز فلسطین': [35.710698, 51.404289],
#  'بلوار کشاورز کارگر': [35.707745, 51.390224],
#  'بیستون': [37.276477, 49.574003],
#  'بیمارستان امام خمینی': [35.707597, 51.380621],
#  'بیهقی': [35.734669, 51.418269],
#  'پارک ساعی': [35.736106, 51.410887],
#  'پارک شفق': [35.729487, 51.408409],
#  'پارک لاله': [35.711186, 51.392906],
#  'پارک هنرمندان': [35.710089, 51.420908],
#  'پروین اعتصامی فاطمی': [35.719061, 51.396918],
#  'توانیر': [35.751667, 51.40843],
#  'جمال زاده': [35.705768, 51.386318],
#  'جهان آرا': [35.736119, 51.402996],
#  'چهارراه کالج': [35.701551, 51.412824],
#  'حجاب': [35.712876, 51.395481],
#  'خردمند جنوبی': [35.713077, 51.421863],
#  'خردمند شمالی': [35.717929, 51.421562],
#  'دکتر قریب': [35.705489, 51.383443],
#  'زرتشت': [31.88266, 54.377834],
#  'ساعی - آبشار': [35.740861, 51.407261],
#  'سپهبد قرنی': [35.708399, 51.418376],
#  'سمیه': [35.705341, 51.419867],
#  'سنایی': [35.720664, 51.418789],
#  'شانزده آذر': [35.704217, 51.392798],
#  'طالقانی': [37.555371, 45.079136],
#  'طالقانی قرنی': [35.706804, 51.418483],
#  'فاطمی': [34.629756, 50.87172],
#  'فاطمی - اعتمادزاده': [35.713323, 51.38467],
#  'فاطمی - حجاب': [35.716169, 51.394043],
#  'فاطمی - کاج': [35.718295, 51.400834],
#  'فاطمی - کارگر': [35.714897, 51.390138],
#  'فتحی شقاقی': [35.723739, 51.406156],
#  'فجر(جم)': [35.721901, 51.423097],
#  'فرصت شیرازی': [35.702535, 51.38546],
#  'فلسطین شمالی': [35.708703, 51.403978],
#  'قائم مقام فراهانی': [35.721674, 51.420608],
#  'قدس': [35.70467, 51.396725],
#  'قزل قلعه': [35.729966, 51.391125],
#  'گاندی جنوبی': [35.749351, 51.412818],
#  'گمنام': [35.724705, 51.39606],
#  'لارستان': [35.7215, 51.413183],
#  'مدبر (مهرام)': [35.733088, 51.403152],
#  'میدان آرژانتین': [35.737107, 51.415404],
#  'میدان انقلاب': [34.069796, 49.657805],
#  'میدان سلماس': [35.723621, 51.402293],
#  'میدان فاطمی': [35.72022, 51.406295],
#  'میدان فرهنگ (میدان اسد آبادی)': [35.737153, 51.40566],
#  'میدان فلسطین': [35.706412, 51.403602],
#  'میدان گلها فاطمی': [35.721814, 51.400051],
#  'میدان ولیعصر': [36.836841, 54.437342],
#  'نصرت': [35.705454, 51.388099],
#  'وزرا (خالد اسلامبولی)': [35.730889, 51.414728],
#  'وصال شیرازی': [35.704513, 51.398957],
#  'ولیعصر آبشار': [35.73783, 51.409058],
#  'ولیعصر بهشتی': [35.727144, 51.413784],
#  'ولیعصر پل همت': [35.751467, 51.411252],
#  'ولیعصر توانیر': [35.747174, 51.41151],
#  'ولیعصر زرتشت': [35.717075, 51.407958],
#  'ولیعصر طالقانی': [35.70643, 51.406145],
#  'ولیعصر فاطمی': [35.720934, 51.408505],
#  'ونک پارک': [35.77183, 51.390717],
#  'کارگر شمالی - بیمارستان قلب': [35.719873, 51.389022],
#  'کارگر شمالی تا گمنام': [35.736446, 51.386619],
#  'کبیر زاده (بلوار لاله)': [35.746652, 51.305037],
#  'کریمخان': [35.715263, 51.418805],
#  'کوکب': [35.714506, 51.374478],
#  'یوسف آباد بالاتر از میدان اسدآبادی': [35.741427, 51.405201],
#  'یوسف آباد پایین تر از میدان اسدآبادی': [35.732509, 51.406274],
#  'ابن یمین': [35.740791, 51.440542],
#  'اجاره دار': [35.720762, 51.451527],
#  'اجاره دار (خواجه نظام)': [35.715455, 51.448942],
#  'ادیبی': [35.718207, 51.442859],
#  'امجدیه (خاقانی)': [35.710855, 51.428611],
#  'اندیشه': [35.728833, 51.442741],
#  'باغ موزه قصر': [35.723486, 51.448535],
#  'بسطامی': [35.7408, 51.444018],
#  'بهار جنوبی': [35.704949, 51.428858],
#  'بهار شمالی': [35.712327, 51.430757],
#  'بهارشیراز': [35.718085, 51.431336],
#  'بهشتی مدرس (عباس آباد)': [35.730036, 51.426959],
#  'پروشات': [35.724488, 51.441606],
#  'پل چوبی': [35.701795, 51.438482],
#  'پلیس': [35.721744, 51.447215],
#  'پیچ شمیران': [35.701812, 51.430306],
#  'ترکمنستان': [35.720838, 51.440005],
#  'چهارراه سهروردی': [35.728433, 51.437023],
#  'چهارراه عباس آباد': [35.731299, 51.442795],
#  'چهارراه قصر': [35.731351, 51.445155],
#  'چهارراه نظام آباد': [35.719601, 51.463641],
#  'حشمتیه': [35.719549, 51.457257],
#  'خرمشهر': [35.735671, 51.436851],
#  'خواجه نصیر طوسی': [35.706726, 51.437613],
#  'خواجه نظام': [35.71082, 51.446142],
#  'خیابان اجاره دار': [35.718366, 51.450207],
#  'خیابان پاکستان': [35.732352, 51.423118],
#  'دبستان (کابلی)': [35.738727, 51.452408],
#  'دماوند از سبلان تا امام حسین': [35.705262, 51.460133],
#  'سبلان جنوبی': [35.713678, 51.467836],
#  'سبلان شمالی': [35.723869, 51.460755],
#  'سپاه': [35.704365, 51.439426],
#  'سرباز': [35.708189, 51.443095],
#  'سلیمان خاطر': [35.721221, 51.431465],
#  'سه راه زندان': [35.720429, 51.442559],
#  'سه راه طالقانی': [35.706752, 51.433761],
#  'سهروردی جنوبی': [35.721343, 51.434255],
#  'سهروردی شمالی': [35.732056, 51.439319],
#  'سورنا (حسینی)': [35.728451, 51.43374],
#  'شریعتی بهارشیراز': [35.716221, 51.436872],
#  'شریعتی پلیس': [35.720838, 51.443803],
#  'شریعتی سمیه': [35.705541, 51.427495],
#  'شریعتی مطهری': [35.723477, 51.443106],
#  'شریعتی معلم': [35.727876, 51.449414],
#  'شریعتی ملک': [35.717641, 51.439812],
#  'شهید قدوسی': [35.729862, 51.452011],
#  'شهید قندی': [35.738928, 51.439973],
#  'صابونچی (مهناز)': [35.733467, 51.432517],
#  'طالقانی بهار': [35.708146, 51.429802],
#  'عشقیار (نیلوفر)': [35.736498, 51.432753],
#  'قنبرزاده': [35.735401, 51.429856],
#  'گرگان': [35.713338, 51.452065],
#  'مدنی از امام علی تا امام حسین': [35.714392, 51.461077],
#  'مرودشت': [35.725193, 51.450691],
#  'مطهری (تخت طاووس)': [35.724374, 51.437538],
#  'مطهری مفتح': [35.724183, 51.427903],
#  'معلم': [35.722955, 51.44581],
#  'مفتح جنوبی': [35.710158, 51.425554],
#  'مفتح شمالی': [35.719009, 51.427989],
#  'ملک': [34.080884, 49.696623],
#  'میدان امام حسین': [34.802483, 48.538906],
#  'میدان بهار شیراز': [35.71711, 51.434126],
#  'میدان پالیزی': [35.738945, 51.444018],
#  'میدان سبلان': [35.730314, 51.458738],
#  'میدان سپاه': [35.825662, 50.977979],
#  'میدان نامجو (گرگان)': [35.716579, 51.45538],
#  'میدان نیلوفر': [35.737952, 51.432672],
#  'میدان هفت تیر': [34.083846, 49.685454],
#  'میرعماد': [35.727284, 51.425714],
#  'نامجو (گرگان)': [35.709061, 51.447623],
#  'نظام آباد': [35.709932, 51.460648],
#  'هویزه شرقی': [35.733911, 51.442924],
#  'هویزه غربی': [35.733641, 51.436239],
#  'ولیعصر تقاطع مطهری': [35.723712, 51.410758],
#  'کشواد': [35.717537, 51.444973],
#  'کلیم کاشانی': [35.720106, 51.445885],
#  'یوسفیان': [35.72143, 51.437731],
#  'آیت پایین تر از رسالت': [35.732805, 51.494164],
#  'اثنی عشری (شانزده متری دوم)': [35.736367, 51.469982],
#  'امیری طائمه': [35.727083, 51.51913],
#  'چهارراه تلفنخانه': [35.720359, 51.491772],
#  'چهارراه تیرانداز': [35.728625, 51.526158],
#  'چهارراه سیدالشهدا': [35.733907, 51.538137],
#  'چهارراه کرمان': [35.732477, 51.477009],
#  'خیابان ثانی': [35.721065, 51.482427],
#  'دردشت': [35.726691, 51.502576],
#  'دماوند باقری تا رسالت': [35.723834, 51.522145],
#  'دماوند باقری تا سبلان': [35.713277, 51.486182],
#  'سمنگان': [35.728607, 51.486526],
#  'فدک': [35.728416, 51.481483],
#  'فلکه اول تهرانپارس': [35.726743, 51.525187],
#  'فلکه چهارم تهرانپارس': [35.750167, 51.537573],
#  'فلکه دوم تهرانپارس': [35.735052, 51.529586],
#  'فلکه سوم تهرانپارس': [35.743203, 51.533883],
#  'گلبرگ شرقی (جانبازان)': [35.728851, 51.506009],
#  'گلبرگ غربی (جانبازان)': [35.731795, 51.466098],
#  'گلشن دوست': [35.71812, 51.478586],
#  'مجیدیه جنوبی': [35.737316, 51.465025],
#  'مدائن': [35.726831, 51.497662],
#  'مدنی از امام علی تا سبلان': [35.707667, 51.451378],
#  'مدنی فدک': [35.72744, 51.476784],
#  'مدنی گلبرگ': [35.73183, 51.48262],
#  'مسیل باختر': [35.728015, 51.467299],
#  'میدان شقایق': [35.719601, 51.50175],
#  'میدان نبوت (هفت حوض)': [35.730027, 51.49366],
#  'میدان هلال احمر': [35.825796, 50.986862],
#  'نارمک': [35.751249, 51.513605],
#  'هفت حوض': [35.733206, 51.490688],
#  'همایی(شانزده متری اول)': [35.736219, 51.468287],
#  'کرمان': [35.735174, 51.478114],
#  'آزادی': [35.7, 51.350849],
#  'استاد معین': [35.692646, 51.345849],
#  'امام خمینی از یادگار تا جیحون': [35.68666, 51.360408],
#  'بیست و یک متری جی': [35.695469, 51.348467],
#  'دامپزشکی از سعیدی تا یادگار': [35.691775, 51.349604],
#  'فرودگاه': [31.895657, 54.306783],
#  'مهرآباد جنوبی': [35.675531, 51.339047],
#  'میدان آزادی': [35.699791, 51.337781],
#  'هاشمی از سعیدی تا یادگار': [35.688777, 51.348124],
#  'آذربایجان از آزادی تا توحید': [35.697316, 51.371727],
#  'امام خمینی از جیهون تا قصرالدشت': [35.687034, 51.367307],
#  'بریانک': [35.676681, 51.376534],
#  'جی': [35.692193, 51.354947],
#  'جیحون': [35.692158, 51.363745],
#  'خوش جنوبی': [35.692559, 51.372805],
#  'خوش شمالی': [35.703154, 51.371523],
#  'خیابان کمیل': [35.680687, 51.366046],
#  'رودکی جنوبی بالاتر از آذربایجان': [35.698223, 51.375246],
#  'زنجان جنوبی': [35.696567, 51.360011],
#  'شهیدان': [35.697055, 51.35529],
#  'طوس': [35.694441, 51.358252],
#  'قصرالدشت': [35.688603, 51.370311],
#  'میدان جمهوری': [35.835597, 50.979441],
#  'هاشمی از یادگار تا نواب': [35.689405, 51.363659],
#  'کارون': [35.692019, 51.366792],
#  'آذربایجان از کارگر تا ولیعصر': [35.693064, 51.394762],
#  'اسکندری': [35.691043, 51.381619],
#  'امام خمینی از حر تا ولیعصر': [35.687522, 51.398485],
#  'امام خمینی از ولیعصر تا حسن آباد': [35.686485, 51.406682],
#  'امیر بهادر': [35.671731, 51.400824],
#  'پارک دانشجو': [35.700488, 51.406467],
#  'جامی': [35.690058, 51.407315],
#  'جمال زاده (حشمت الدوله)': [35.697308, 51.388598],
#  'جمهوری از میدان تا کارگر': [35.696463, 51.385331],
#  'جمهوری از ولیعصر تا حافظ': [35.695278, 51.408055],
#  'جمهوری از کارگر تا ولیعصر': [35.695818, 51.398098],
#  'جمهوری-کارگر تا اسکندری': [35.774881, 51.396411],
#  'چهارراه لشگر': [35.682363, 51.393614],
#  'چهارراه ولیعصر': [35.701185, 51.405201],
#  'حافظ شمالی': [37.252592, 55.169263],
#  'حافظ طالقانی': [35.706526, 51.412218],
#  'حافظ نوفل لوشاتو': [35.697273, 51.412207],
#  'خابان وحدت اسلامی (حسن آباد)': [35.672786, 51.407486],
#  'خیابان آذربایجان-کارگر تا اسکندری': [35.693628, 51.386901],
#  'دوازده فروردین': [35.698162, 51.394783],
#  'رازی': [35.780503, 50.8935],
#  'شهدای ژاندارمری': [35.700061, 51.397465],
#  'شیخ هادی': [35.691496, 51.406145],
#  'قزوین ولیعصر': [35.668105, 51.373873],
#  'مصطفی خمینی': [34.095904, 49.719186],
#  'مولوی از محمدیه تا چهارراه مولوی': [35.667495, 51.410995],
#  'میدان پاستور': [35.690886, 51.392498],
#  'میدان حر': [35.688089, 51.392895],
#  'میدان حسن آباد': [35.686111, 51.41019],
#  'میدان راه آهن': [34.074113, 49.702781],
#  'میدان قزوین': [35.675296, 51.394547],
#  'میدان منیریه': [35.681152, 51.401618],
#  'نوفل لوشاتو حافظ تا ولیعصر': [35.697038, 51.408162],
#  'هلال احمر': [35.667983, 51.385546],
#  'ولیعصر آذربایجان': [35.692742, 51.397594],
#  'ولیعصر امام خمینی': [35.686965, 51.402626],
#  'ولیعصر جمهوری': [35.695469, 51.404257],
#  'ولیعصر منیریه': [35.68449, 51.402283],
#  'کارگر جنوبی از انقلاب تا میدان پاستور': [35.695469, 51.391897],
#  'کارگر جنوبی از حر تا قزوین': [35.685292, 51.393228],
#  'ابن سینا': [35.698048, 51.436572],
#  'ابن سینا بهارستان': [35.69418, 51.43434],
#  'امام زاده یحیی': [35.677631, 51.434652],
#  'امیرکبیر': [37.232791, 55.179498],
#  'ایران': [35.688594, 51.439474],
#  'بازار بزرگ تهران': [35.672433, 51.422383],
#  'بلوار قیام': [35.669186, 51.440874],
#  'پامنار': [35.681771, 51.428118],
#  'پانزده خرداد': [35.675914, 51.428676],
#  'پیروزی - شکوفه': [35.681945, 51.453094],
#  'جمهوری از فردوسی تا حافظ': [35.694877, 51.415887],
#  'جمهوری بهارستان': [35.692115, 51.427227],
#  'جمهوری فردوسی': [35.694668, 51.419857],
#  'چهارراه اسلامبول': [35.693143, 51.424524],
#  'حافظ بعد از پل کالج': [35.700052, 51.412776],
#  'خراسان': [35.66671, 51.440349],
#  'خیابان ری': [35.675531, 51.438332],
#  'دروازه دولت': [35.701642, 51.426042],
#  'دروازه شمیران': [35.696968, 51.443911],
#  'زرین نعل': [35.693936, 51.445735],
#  'سعدی': [37.286926, 49.584131],
#  'سی تیر': [35.691078, 51.414213],
#  'شوش از میدان شوش تا هفده شهریور': [35.660173, 51.438396],
#  'صفی علیشاه': [35.698501, 51.432474],
#  'فردوسی': [37.515741, 45.063594],
#  'فلسطین جنوبی از انقلاب تا جمهوری': [35.698467, 51.402261],
#  'فلسطین جنوبی پایین تر از جمهوری': [35.694406, 51.401768],
#  'گوته': [35.682703, 51.443707],
#  'مازندران': [35.700348, 51.442666],
#  'مردم': [35.690137, 51.4361],
#  'منوچهری': [34.807122, 48.48972],
#  'مولوی': [35.668595, 51.42319],
#  'مولوی (میدان مولوی تا خیابان مصطفی خمینی)': [35.668595, 51.42319],
#  'میدان امام خمینی (توپ خانه)': [35.685753, 51.421493],
#  'میدان بهارستان': [35.841555, 51.019886],
#  'میدان خراسان': [35.665368, 51.445606],
#  'میدان شهداء (هفده شهریور)': [35.68971, 51.447258],
#  'میدان شوش': [35.659755, 51.430843],
#  'میدان فردوسی': [35.701542, 51.419084],
#  'میدان قیام': [35.669657, 51.436261],
#  'نوفل لوشاتو فردوسی تا حافظ': [35.697526, 51.416144],
#  'هفده شهریور جنوب میدان شهداء': [35.68191, 51.446571],
#  'هفده شهریور شمال میدان شهداء': [35.696131, 51.447816],
#  'وحدت اسلامی': [35.663607, 51.405759],
#  'کوچه مروی': [35.678773, 51.423944],
#  'امامت': [35.710315, 51.488628],
#  'پیروزی': [35.69152, 51.473455],
#  'پیروزی - ۱ تا ۵ نیرو هوایی': [35.698432, 51.48365],
#  'پیروزی - سی متری نیروی هوایی': [35.700924, 51.490002],
#  'فلکه اطلاعات': [35.713652, 51.499057],
#  'فلکه لوزی': [35.700636, 51.497812],
#  'مسیل جاجرود': [35.711814, 51.496482],
#  'مسیل منوچهری': [35.703102, 51.492491],
#  'میدان امامت (وثوق)': [35.713255, 51.489862],
#  'میدان چایچی': [35.709448, 51.500918],
#  'آهنگ شرقی (ده حقی)': [35.656634, 51.483564],
#  'آهنگ غربی (ده حقی)': [35.658552, 51.471419],
#  'پیروزی - بلوار ابوذر': [35.673858, 51.488478],
#  'پیروزی - پرستار': [35.687766, 51.486053],
#  'پیروزی - دهم فروردین شمالی': [35.675444, 51.474123],
#  'پیروزی - صد دستگاه': [35.68801, 51.472063],
#  'پیروزی - نبرد شمالی': [35.679854, 51.479959],
#  'چهارصد دستگاه': [35.817854, 50.984305],
#  'خاوران': [35.665699, 51.453266],
#  'سر آسیاب': [35.681196, 51.462729],
#  'مجاهدین اسلام': [35.69201, 51.440831],
#  'محلاتی - دهم فروردین جنوبی': [35.664575, 51.471977],
#  'نبرد - پاسدار گمنام': [35.671731, 51.481075],
#  'افسریه': [35.653052, 51.493431],
#  'بلوار ابوذر - زمزم': [35.661521, 51.481648],
#  'محلاتی - نبرد جنوبی': [35.653617, 51.478773],
#  'کیانشهر': [35.637662, 51.451764],
#  'جوادیه': [34.125901, 49.712234],
#  'علی آباد': [35.627652, 51.419964],
#  'میدان کلانتری': [35.639741, 51.412185],
#  'نازی آباد': [35.644951, 51.402025],
#  'ابوذر - فلاح': [35.657087, 51.369066],
#  'امام زاده حسن': [35.664803, 51.360183],
#  'بلوار مدائن': [35.661664, 51.319424],
#  'بلوار معلم': [37.283648, 49.57778],
#  'خزانه ( فلاح )': [35.652372, 51.359035],
#  'سه راه آذری': [35.670424, 51.352222],
#  'شاد آباد': [35.658074, 51.303245],
#  'میدان گلچین': [35.653877, 51.36676],
#  'یافت آباد': [35.662552, 51.350141],
#  'یافت آباد غربی': [35.665604, 51.318094],
#  'آشتیانی (جواد الائمه)': [35.658377, 51.270232],
#  'میدان الغدیر': [35.821049, 50.928462],
#  'بهمنیار': [35.633477, 51.395588],
#  'خانی آباد': [35.632186, 51.38988],
#  'شکوفه': [35.630686, 51.366191],
#  'نعمت آباد': [35.631874, 51.353929],
#  'بلوار دیلمان': [35.602602, 51.435585],
#  'پروین اعتصامی دولت آباد': [35.618338, 51.441979],
#  'جوانمرد قصاب': [35.613628, 51.426315],
#  'دولت آباد': [35.810074, 50.973501],
#  'دیلمان': [37.305293, 49.598637],
#  'سه راه ورامین': [35.597194, 51.439673],
#  'شهرک شهید مفتح': [35.571541, 51.455541],
#  'شهید غیوری': [35.602236, 51.440949],
#  'میدان شهرری': [35.590834, 51.437527],
#  'میدان نماز': [35.603064, 51.425897],
#  'میدان هادی ساعی': [35.588984, 51.426895],
#  'بلوار گلها': [35.692716, 51.264954],
#  'تهرانسر': [35.696092, 51.257425],
#  'شهرک دانشگاه': [31.850477, 54.356438],
#  'شهرک شهید غزالی': [35.73014, 51.16436],
#  'بلوار کوهک': [35.731638, 51.248302],
#  'دریاچه چیتگر': [35.747557, 51.221008],
#  'دهکده المپیک': [35.761272, 51.261735],
#  'شهرک چشمه': [35.749028, 51.259187],
#  'شهرک چیتگر': [35.749177, 51.189294],
#  'شهرک شهید باقری': [35.763264, 51.205044],
#  'شهرک شهید صیاد شیرازی': [35.754505, 51.199894],
#  'شهرک صدرا': [35.74234, 51.258028],
#  'شهرک گلستان': [31.826028, 54.364],
#  'شهرک نمونه': [35.760377, 51.231592],
#  'میدان دریاچه': [35.753382, 51.208928],
#  'هوانیروز': [35.744555, 51.236825],
#  '۱۹ دی (باجک ۲)': [34.657947, 50.903555],
#  'ابتدای شهرک قدس': [34.602713, 50.832639],
#  'ابتدای صدوقی': [34.626925, 50.860898],
#  'ابوطالب': [34.545416, 50.825672],
#  'امام خمینی - تولید دارو': [34.663263, 50.875776],
#  'امام خمینی (میدان سعیدی)': [34.650226, 50.877771],
#  'امامزاده ابراهیم': [34.657657, 50.85876],
#  'انتهای شهرک قدس': [34.592044, 50.850875],
#  'انسجام': [34.604831, 50.878801],
#  'انصار\u200cالحسین': [34.675164, 50.881634],
#  'انقلاب (چهارمردان)': [34.635062, 50.891118],
#  'باجک ۳': [34.66686, 50.912632],
#  'بزرگراه عمار یاسر': [34.652644, 50.905151],
#  'بلوار ۱۵ خرداد': [34.636757, 50.911846],
#  'بلوار الغدیر': [34.555918, 50.776696],
#  'بلوار امام رضا': [35.837159, 50.997119],
#  'بلوار امام علی': [34.550097, 50.817471],
#  'بلوار امامت': [34.54287, 50.831766],
#  'بلوار امین': [34.623797, 50.852365],
#  'بلوار بنی فضل': [34.631637, 50.848031],
#  'بلوار بنی فضل - بلوار توحید': [34.652636, 50.835629],
#  'بلوار پیامبر': [34.613255, 50.895796],
#  'بلوار توحید': [34.648673, 50.85022],
#  'بلوار حضرت خدیجه': [34.60038, 50.895839],
#  'بلوار دل آذر - میدان پلیس': [34.625945, 50.907431],
#  'بلوار شاهد شرقی': [34.634638, 50.842066],
#  'بلوار شاهد غربی': [34.63093, 50.835114],
#  'بلوار شهروند': [34.564577, 50.803628],
#  'بلوار شهید روحانی': [34.636403, 50.903392],
#  'بلوار شهید کریمی': [34.598419, 50.87657],
#  'بلوار فردوسی': [34.608681, 50.868931],
#  'بلوار کاشانی': [34.651832, 50.859489],
#  'پردیسان': [34.55736, 50.810223],
#  'پیام نور': [34.652693, 50.914357],
#  'جامعه الزهرا': [34.615762, 50.849705],
#  'جمهوری اسلامی': [34.616787, 50.876484],
#  'جمهوری اسلامی (سمت نیروگاه)': [34.637427, 50.858159],
#  'جمکران': [34.584871, 50.914378],
#  'حرم': [34.6414, 50.877943],
#  'خیابان ۱۹ دی (باجک 1)': [34.648973, 50.889702],
#  'خیابان ۲۰ متری شهید کرمی': [34.645372, 50.865111],
#  'خیابان سمیه': [34.629377, 50.881162],
#  'خیابان طالقانی': [34.076516, 49.672778],
#  'خیابان میثم': [34.668706, 50.862579],
#  'خیابان هنرستان': [34.629412, 50.892191],
#  'خیام': [35.818083, 50.954696],
#  'دانشگاه آزاد قم': [34.641912, 50.908198],
#  'دانیال': [34.612619, 50.873308],
#  'دل آذر': [34.61872, 50.910537],
#  'سالاریه': [34.618252, 50.844941],
#  'سوم خرداد پایین تر از بلوار کارگر': [34.662723, 50.857644],
#  'شهرک زین الدین': [34.593562, 50.877814],
#  'شهرک قدس': [34.599461, 50.836637],
#  'شهرک مهدیه': [34.582556, 50.823612],
#  'شهرک ولایت': [34.619842, 50.886054],
#  'شهرک کریمی': [34.596317, 50.868287],
#  'شهید آوینی': [34.598099, 50.844049],
#  'شهید صدوقی (زنبیل\u200c آباد)': [34.611913, 50.857687],
#  'صفائیه': [34.635459, 50.869424],
#  'صفاشهر': [34.606773, 50.844512],
#  'عطاران': [34.621042, 50.864897],
#  'لقمان': [34.602217, 50.867558],
#  'مدرس': [34.087796, 49.709101],
#  'میدان شهرداری': [34.664919, 50.900358],
#  'میدان صدوقی': [34.619527, 50.859288],
#  'میدان مفید': [34.602511, 50.855426],
#  'میدان نواب': [34.667743, 50.892848],
#  'نیروی هوایی': [34.662546, 50.838375],
#  'هفت تیر': [34.66267, 50.889101],
#  'کلهری': [34.617705, 50.906096],
#  'کیوانفر': [34.657745, 50.883694],
#  'یادگار امام': [34.106323, 49.71173],
#  'اوزيها': [27.178315, 56.27117],
#  'بلوار آزادگان': [37.518962, 45.05918],
#  'بلوار امام حسين، آزادگان': [27.206726, 56.310541],
#  'بلوار چمران': [27.184373, 56.306925],
#  'چهار راه پرديس': [27.205342, 56.332486],
#  'خواجه عطا، نایبند': [27.190599, 56.319514],
#  'سه راه برق': [27.196994, 56.27317],
#  'شهرک 22 بهمن': [27.185912, 56.262587],
#  'شهرک طلوع': [27.196262, 56.334951],
#  'گلشهر جنوبی': [36.814396, 54.45665],
#  'گلشهر شمالی': [36.828409, 54.456189],
#  'محله پشت شهر': [27.174555, 56.262995],
#  'محله چاهستانی ها': [27.202281, 56.294799],
#  'مرکز شهر': [27.18177, 56.285912],
#  'میدان شریعتی': [34.077654, 49.677134],
#  '45 متری گلشهر': [35.834124, 50.941411],
#  '۴۵ متری کاج': [35.830375, 51.010036],
#  'آسیاب برجی': [35.799632, 50.982224],
#  'اراضی انصاری': [35.818502, 50.970766],
#  'اسلام آباد': [37.567381, 45.106306],
#  'اشتراکی جنوبی': [35.859842, 50.963602],
#  'انوشیروان شرقی': [35.813755, 50.966788],
#  'انوشیروان غربی': [35.815328, 50.950218],
#  'اوقافیها': [35.846386, 50.963103],
#  'باغستان': [35.867976, 50.96354],
#  'باغستان غربی': [35.879597, 50.956135],
#  'بام کرج': [35.84737, 51.013427],
#  'باهنر': [35.812073, 50.879402],
#  'بلستان': [35.844258, 50.913124],
#  'بلوار آقارضایی': [35.848007, 50.920727],
#  'بلوار ارم': [35.811185, 50.90292],
#  'بلوار اصناف': [35.867676, 50.918498],
#  'بلوار انقلاب': [34.817916, 48.519731],
#  'بلوار باهنر': [35.85964, 50.943496],
#  'بلوار بهشتی گلستانک': [35.761668, 50.913348],
#  'بلوار پونه شرقی': [35.825291, 50.942144],
#  'بلوار خبرنگار': [35.77185, 50.923991],
#  'بلوار خوارزمی': [35.855093, 50.920817],
#  'بلوار رستاخیز': [35.856897, 50.97254],
#  'بلوار شهرداری': [35.852149, 50.964793],
#  'بلوار مطهری': [35.840074, 50.989676],
#  'بلوار ملکشاه': [35.846601, 50.980265],
#  'بلوار موذن': [35.849858, 50.984888],
#  'بلوار ناصربخت': [35.84571, 50.947822],
#  'بلوار هوشیار': [35.830966, 50.930321],
#  'بلوار ولایت': [35.691961, 51.009436],
#  'بلوار ولیعصر': [35.817436, 50.897083],
#  'پیشاهنگی': [35.858102, 50.899209],
#  'جهانشهر': [35.829037, 50.985449],
#  'چمن': [35.787796, 50.917511],
#  'چهار راه پونه': [35.824647, 50.947172],
#  'چهار راه طالقانی': [35.821018, 50.990152],
#  'چهار راه گلزار': [35.821635, 50.939752],
#  'چهار راه هفت تیر': [35.812424, 50.986433],
#  'چهار راه کارخانه قند': [35.808159, 50.987463],
#  'چهارراه مصباح': [35.801927, 50.99081],
#  'حاجی آباد': [35.837195, 50.989008],
#  'حافظ': [35.764815, 50.920483],
#  'حسن آباد': [35.845117, 51.002162],
#  'حسین آباد': [37.572002, 45.085895],
#  'حصارک بالا': [35.850339, 50.922317],
#  'حصارک پایین': [35.842394, 50.918627],
#  'حیدر آباد': [35.839939, 50.944875],
#  'خوشنام': [35.697201, 50.93914],
#  'خیابان بهار': [35.82107, 50.995882],
#  'خیابان قلم': [35.848092, 50.943881],
#  'خیابان محراب': [35.752105, 50.903027],
#  'خیابان کسری': [35.828981, 50.981798],
#  'درختی': [35.818349, 50.940333],
#  'دهقان ویلا اول': [35.826828, 50.961554],
#  'دهقان ویلا دوم': [35.829101, 50.952895],
#  'ذوب آهن': [35.789289, 50.989088],
#  'رزکان': [35.773397, 50.977335],
#  'ساسانی': [35.797102, 50.995508],
#  'سرآسیاب': [35.685269, 50.977507],
#  'سرحد آباد': [35.775813, 51.009596],
#  'سه راه گوهردشت': [35.82908, 50.967161],
#  'شاهین ویلا': [35.862228, 50.952802],
#  'شهرک اداری': [35.682422, 51.040764],
#  'شهرک اوج': [35.847752, 50.99463],
#  'شهرک بنفشه': [35.782705, 50.999805],
#  'شهرک بهارستان': [36.848726, 54.444768],
#  'شهرک جهازیها': [35.859028, 50.983701],
#  'شهرک جهان نما': [35.787256, 51.034315],
#  'شهرک مریم': [35.664758, 51.008663],
#  'شهرک ناز': [35.719758, 50.950127],
#  'شهرک وایین': [35.672522, 51.040421],
#  'شهید حسین علیزاده': [35.76492, 50.911664],
#  'شهید خوشبویی': [35.849306, 50.919249],
#  'شهید ساسانی': [35.853826, 50.92308],
#  'شهیدبهشتی': [35.838317, 50.938303],
#  'صاحب الزمان': [35.762884, 50.899165],
#  'صفا دشت': [35.672358, 50.839233],
#  'عباس آباد': [35.720812, 50.873566],
#  'عظیمی': [35.763187, 50.915623],
#  'عظیمیه': [35.835002, 51.019478],
#  'فاز 4 مهرشهر': [35.81259, 50.940104],
#  ...}

# %% [markdown]
# # Scrape using APIs
# ### Records
#
#
# <b>Extract Number of records for each city and area. </b>

# %%
records=[]
for cityid in city_id:
    url1  = "https://www.delino.com/restaurant/search/?cityid="+str(cityid)+"&offset=0&limit=12&_=1675373603471"
    page1 = requests.get(url1)
    j1    = json.loads(page1.text)
    records.append(j1['total'])

    
records2 = []
for geo in lat_lng:
    url1    = "https://www.delino.com/restaurant/search/?lat="+str(geo[0])+"&lng="+str(geo[1])+"&sort=distance&limit=12&_=1675705029664"
    session = requests.Session()
    retry   = Retry(connect=3, backoff_factor=0.5)
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    page1   = session.get(url1)
    j1      = json.loads(page1.text)
    records2.append(j1['total'])

# %% [markdown]
# # Scrape using APIs
# ### Restaurants
#
#
# <b>Extract restaurants and their information. </b>

# %%
All_restaurants = []
for cityid, record in zip(city_id, records):
    url_record  = record // 12 + 1
    for i in range(0,url_record):
        url2    = "https://www.delino.com/restaurant/search/?cityid="+str(cityid)+"&offset="+str(12*i)+"&limit=12&_=1675373603471"
        session = requests.Session()
        retry   = Retry(connect=3, backoff_factor=0.5)
        adapter = HTTPAdapter(max_retries=retry)
        session.mount('http://', adapter)
        session.mount('https://', adapter)
        page2   = session.get(url2)
        j2      = json.loads(page2.text)
        for k in range(len(j2['result'])):
            restaurants_info                   = {}
            restaurants_info['Restaurant_Id']  = j2['result'][k]['id']
            restaurants_info['Name']           = j2['result'][k]['name']
            restaurants_info['Rate']           = j2['result'][k]['rate']
            restaurants_info['Count of Rates'] = j2['result'][k]['rateCount']
            restaurants_info['deliveryTime']   = j2['result'][k]['deliveryTime']
            restaurants_info['City Name']      = city_name_id[j2['result'][k]['cityId']]
            restaurants_info["Address"]        = j2['result'][k]['fullAddress']
            restaurants_info['Latitude']       = j2['result'][k]['lat']
            restaurants_info['Longitude']      = j2['result'][k]['lng']
            All_restaurants.append(restaurants_info)
            
            
df = pd.DataFrame(All_restaurants)
df.to_csv('All_Restaurants_in_Delino.csv')
df
# Out:
#                              Restaurant_Id                   Name  Rate  \
# 0     4d6f01fe-3279-4064-9c1c-6693cf533e54   کافه رستوران نایریکا  4.06
# 1     fdfa5aaf-2d9b-4b0e-a2ec-25fdaab3f835  رستوران شاندیز گالریا  4.73
# 2     ebb5ece2-07e6-4900-85e0-3c353fa449ac          رستوران چاشنی  3.90
# 3     f90df589-1b38-49d4-92ff-615f26de5863        رستوران طهرونچی  4.16
# 4     cf9670ae-ebb1-4f9f-9689-7feb1f09aaeb     آش و حلیم سید مهدی  3.99
# ...                                    ...                    ...   ...
# 1237  17f25b56-79b9-49d4-b55e-ac70c1d2d060        رستوران بانی چو  0.00
# 1238  0c04b0eb-2f81-4661-b2e9-7aabd2d9c2f8          رستوران ژیوان  0.00
# 1239  1f43d015-821b-4b52-b5db-8a677056efd4               پیتزا تک  0.00
# 1240  e4173814-c658-4a0d-8cf4-39b16ded7714        تهیه غذای غذاچی  0.00
# 1241  e34a4d8e-1e2a-4703-ab34-1efb3938946a   کافه رستوران ماتادور  0.00
#
#       Count of Rates    deliveryTime City Name  \
# 0               96.0  30 تا 55 دقیقه     تهران
# 1               75.0  35 تا 65 دقیقه     تهران
# 2              102.0  60 تا 90 دقیقه     تهران
# 3               43.0  40 تا 60 دقیقه     تهران
# 4              123.0  40 تا 55 دقیقه     تهران
# ...              ...             ...       ...
# 1237             0.0  30 تا 60 دقیقه      اراک
# 1238             0.0  20 تا 40 دقیقه      اراک
# 1239             0.0  40 تا 60 دقیقه      اراک
# 1240             0.0  30 تا 50 دقیقه      اراک
# 1241             0.0  30 تا 50 دقیقه      اراک
#
#                                                 Address   Latitude  Longitude
# 0     خیابان پونک، خیابان مخبری (35 متری گلستان)، نر...  35.756177  51.324939
# 1                خیابان ولنجک، خیابان13، پلاک 5، طبقه 6  35.807416  51.404868
# 2     شریعتی، ابتدای دولت، جنب حسینیه یزدی ها، پلاک 403  35.777941  51.443020
# 3          خیابان میرداماد، کوچه دفینه، رستوران طهرونچی  35.762086  51.413706
# 4               اندرزگو، نرسیده به میدان صالحی، پلاک 16  35.801636  51.458502
# ...                                                 ...        ...        ...
# 1237             اراک، خیابان شریعتی، نبش کوچه بانک ملت  34.077674  49.688839
# 1238               اراک، خیابان شریعتی، نبش کوچه پامچال  34.076947  49.697736
# 1239  اراک، سه راه ابوذر، خیابان ابوذر، روبروی نانوا...  34.095735  49.682997
# 1240            اراک-میدان امام حسین-جنب مسجد امام حسین  34.120778  49.704163
# 1241  اراک، خیابان شیرودی(خرم)، نبش کوچه مبارزان، جن...  34.076281  49.702661
#
# [1242 rows x 9 columns]

# %% [markdown]
# # Scrape using APIs
# ### Restaurants
#
#
# <b>Extract resaurants and their areas. </b>

# %%
All_restaurants_by_area=[]
for geo, record2 in zip(lat_lng, records2):
    url_record2 = record2 // 12 + 1
    for offset in range(url_record2):
        url0    = "https://www.delino.com/restaurant/search/?lat="+str(geo[0])+"&lng="+str(geo[1])+"&offset="+str(12*offset)+"&limit=12"
        session = requests.Session()
        retry   = Retry(connect=3, backoff_factor=0.5)
        adapter = HTTPAdapter(max_retries=retry)
        session.mount('http://', adapter)
        session.mount('https://', adapter)
        page0   = session.get(url0)
        j0      = json.loads(page0.text)
        for i in range(len(j0['result'])):
            restaurant_area         = {}
            restaurant_area['Name'] = j0['result'][i]['name']
            restaurant_area['City'] = city_name_id[j0['result'][i]['cityId']]
            restaurant_area['area'] = j0['area']['text']
            All_restaurants_by_area.append(restaurant_area)
            
df0 = pd.DataFrame(All_restaurants_by_area)
df0.to_csv('All_Restaurants_by_area_in_Delino.csv')
df0
# Out:
#                          Name   City      area
# 0              فست فود صاب وی    کرج       110
# 1      آبمیوه و بستنی تو دلیا    کرج       110
# 2                        خروس  تهران       110
# 3       رستوران شاندیز گالریا  تهران  آجودانیه
# 4              کافه GRAB & GO  تهران  آجودانیه
# ...                       ...    ...       ...
# 63856         رستوران بانی چو   اراک  کوی کوثر
# 63857      کافه رستوران اسکای   اراک  کوی کوثر
# 63858       رستوران عقیق اراک   اراک  کوی کوثر
# 63859              پیتزا سنگی   اراک  کوی کوثر
# 63860         تهیه غذای غذاچی   اراک  کوی کوثر
#
# [63861 rows x 3 columns]

# %% [markdown]
# # Scrape using APIs
# ### Foods
#
#
# <b>Extract foods of each restaurant and their information. </b>

# %%
All_foods = []
for i in range(len(All_restaurants)):
    id1     = All_restaurants[i]['Restaurant_Id']
    url3    = "https://www.delino.com/restaurant/menu/" + id1
    session = requests.Session()
    retry   = Retry(connect=3, backoff_factor=0.5)
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    page3   = session.get(url3)
    if (
    page3.status_code != 204 and
    page3.headers["content-type"].strip().startswith("application/json")
    ):
        try:
            j3 = json.loads(page3.text)
        except ValueError:
            continue
    for j in range(len(j3['categories'])):
        for jj in range(len(j3['categories'][j]['sub'][0]['food'])):
            Restaurants_food                          = {}
            Restaurants_food["Id"]                    = id1
            Restaurants_food["Name"]                  = All_restaurants[i]["Name"]
            Restaurants_food["City Name"]             = All_restaurants[i]["City Name"]
            Restaurants_food["Food_Category"]         = j3['categories'][j]['title']
            Restaurants_food["Title"]                 = j3['categories'][j]['sub'][0]['food'][jj]['title']
            Restaurants_food["Ingredient"]            = j3['categories'][j]['sub'][0]['food'][jj]['ingredient']
            Restaurants_food["Price"]                 = j3['categories'][j]['sub'][0]['food'][jj]['price']
            Restaurants_food["Discount(%)"]           = j3['categories'][j]['sub'][0]['food'][jj]['discountPercentage']
            try:
                Restaurants_food["Food Tag"]          = j3['categories'][j]['sub'][0]['food'][jj]['foodTag'][0]['tag']
            except IndexError:
                Restaurants_food["Food Tag"]          = '-------------'
            Restaurants_food["Sale On Ramadan"]       = j3['categories'][j]['sub'][0]['food'][jj]['saleOnRamadan']
            Restaurants_food["Sale On Breakfast"]     = j3['categories'][j]['sub'][0]['food'][jj]['saleOnBreakfast']
            Restaurants_food["Sale On Noon"]          = j3['categories'][j]['sub'][0]['food'][jj]['saleOnNoon']
            Restaurants_food["Sale On Night"]         = j3['categories'][j]['sub'][0]['food'][jj]['saleOnNight']
            Restaurants_food["Delino Recommendation"] = j3['categories'][j]['sub'][0]['food'][jj]['delinoRecommendation']
            All_foods.append(Restaurants_food)



df1 = pd.DataFrame(All_foods)
df1.to_csv("All_foods_in_Delino.csv")
df1
# Out:
#                                          Id                  Name City Name  \
# 0      4d6f01fe-3279-4064-9c1c-6693cf533e54  کافه رستوران نایریکا     تهران
# 1      4d6f01fe-3279-4064-9c1c-6693cf533e54  کافه رستوران نایریکا     تهران
# 2      4d6f01fe-3279-4064-9c1c-6693cf533e54  کافه رستوران نایریکا     تهران
# 3      4d6f01fe-3279-4064-9c1c-6693cf533e54  کافه رستوران نایریکا     تهران
# 4      4d6f01fe-3279-4064-9c1c-6693cf533e54  کافه رستوران نایریکا     تهران
# ...                                     ...                   ...       ...
# 66479  e34a4d8e-1e2a-4703-ab34-1efb3938946a  کافه رستوران ماتادور      اراک
# 66480  e34a4d8e-1e2a-4703-ab34-1efb3938946a  کافه رستوران ماتادور      اراک
# 66481  e34a4d8e-1e2a-4703-ab34-1efb3938946a  کافه رستوران ماتادور      اراک
# 66482  e34a4d8e-1e2a-4703-ab34-1efb3938946a  کافه رستوران ماتادور      اراک
# 66483  e34a4d8e-1e2a-4703-ab34-1efb3938946a  کافه رستوران ماتادور      اراک
#
#       Food_Category                Title  \
# 0             پیتزا        پیتزا باهاماس
# 1             پیتزا         پیتزا پپرونی
# 2             پیتزا       پیتزا آفریکانو
# 3             پیتزا         پیتزا سوپریم
# 4             پیتزا  پیتزا مخصوص نایریکا
# ...             ...                  ...
# 66479       نوشیدنی           دلستر لیمو
# 66480       نوشیدنی            دلستر هلو
# 66481       نوشیدنی        دلستر استوایی
# 66482       نوشیدنی      لیموناد ماتادور
# 66483       نوشیدنی         دلستر کلاسیک
#
#                                               Ingredient   Price  Discount(%)  \
# 0      ژامبون گوشت، ژامبون مرغ، سوسیس ژاپنی، سس مخصوص...  156000            0
# 1                     پپرونی، سس مخصوص، قارچ، زیتون، ذرت  154000            0
# 2             فیله مرغ، سس مخصوص، قارچ، زیتون، فلفل دلمه  162000            0
# 3          بیکن، کراکف، سس مخصوص، قارچ، ذرت، گوجه گیلاسی  163000            0
# 4      گوشت استیک، گوشت مرغ، قارچ، سس مخصوص، زیتون، ذ...  171000            0
# ...                                                  ...     ...          ...
# 66479                                                      12500            0
# 66480                                                      12500            0
# 66481                                                      12500            0
# 66482                                                      12500            0
# 66483                                                      10000            0
#
#             Food Tag  Sale On Ramadan  Sale On Breakfast  Sale On Noon  \
# 0      -------------            False              False          True
# 1      -------------            False              False          True
# 2      -------------            False              False          True
# 3      -------------            False              False          True
# 4      -------------            False              False          True
# ...              ...              ...                ...           ...
# 66479  -------------            False              False          True
# 66480  -------------            False              False          True
# 66481  -------------            False              False          True
# 66482  -------------            False              False          True
# 66483  -------------            False              False          True
#
#        Sale On Night  Delino Recommendation
# 0               True                  False
# 1               True                  False
# 2               True                  False
# 3               True                  False
# 4               True                  False
# ...              ...                    ...
# 66479           True                  False
# 66480           True                  False
# 66481           True                  False
# 66482           True                  False
# 66483           True                  False
#
# [66484 rows x 14 columns]

# %% [markdown]
# # Save CSV dataset
#
#
# <b>Save CSV datasets using the dataframes. </b>

# %%
import zlib
import zipfile


def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("project1.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)


file_names = ["All_Restaurants_in_Delino", "All_foods_in_Delino.csv", 'All_Restaurants_by_area_in_Delino.csv', "Delino_WS.ipynb"]
compress(file_names)
# Out:
# File Paths:
# ['All_Restaurants_in_Delino', 'All_foods_in_Delino.csv', 'All_Restaurants_by_area_in_Delino.csv', 'Delino_WS.ipynb']

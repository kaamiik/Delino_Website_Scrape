# %%
df1
# Out:
#     Unnamed: 0  city_id   City Name
# 0            0        3       تهران
# 1        34613        5          قم
# 2        41135        2    بندرعباس
# 3        41524        7         کرج
# 4        44053        4         رشت
# 5        44486        8       گرگان
# 6        53385        6       همدان
# 7        53530       10         یزد
# 8        57053        1      ارومیه
# 9        60827        9  گنبد کاووس
# 10       61278        0        اراک

# %%
import pandas as pd
df1 = pd.read_csv('/content/drive/MyDrive/All_Restaurants_in_Delino.csv')
df2 = pd.read_csv('/content/drive/MyDrive/All_Restaurants_by_area_in_Delino.csv')
df3 = pd.read_csv('/content/drive/MyDrive/All_foods_in_Delino.csv')

# %%
df1
# Out:
#       Unnamed: 0                         Restaurant_Id  \
# 0              0  b7a0bf69-a22c-45c7-85db-4ed98b3fa1f6
# 1              1  822aec45-fcb3-47df-bab7-84a192e25b9d
# 2              2  f865b321-76dd-4c9f-90d1-c4baa8b40976
# 3              3  67967d9f-653f-4c32-ac52-0cfa3e7d9202
# 4              4  ee8c4172-c733-4e68-bbf5-6658142d7597
# ...          ...                                   ...
# 1237        1237  17f25b56-79b9-49d4-b55e-ac70c1d2d060
# 1238        1238  0c04b0eb-2f81-4661-b2e9-7aabd2d9c2f8
# 1239        1239  1f43d015-821b-4b52-b5db-8a677056efd4
# 1240        1240  e4173814-c658-4a0d-8cf4-39b16ded7714
# 1241        1241  e34a4d8e-1e2a-4703-ab34-1efb3938946a
#
#                         Name  Rate  Count of Rates    deliveryTime City Name  \
# 0          رستوران نیدا لانژ  4.13            16.0  20 تا 40 دقیقه     تهران
# 1          فست فود تی تی هات  3.77            78.0  40 تا 55 دقیقه     تهران
# ...

# %%
df1=df1.drop_duplicates(subset=['Name'])
df1
# Out:
#       Unnamed: 0                         Restaurant_Id  \
# 0              0  b7a0bf69-a22c-45c7-85db-4ed98b3fa1f6
# 1              1  822aec45-fcb3-47df-bab7-84a192e25b9d
# 2              2  f865b321-76dd-4c9f-90d1-c4baa8b40976
# 3              3  67967d9f-653f-4c32-ac52-0cfa3e7d9202
# 4              4  ee8c4172-c733-4e68-bbf5-6658142d7597
# ...          ...                                   ...
# 1237        1237  17f25b56-79b9-49d4-b55e-ac70c1d2d060
# 1238        1238  0c04b0eb-2f81-4661-b2e9-7aabd2d9c2f8
# 1239        1239  1f43d015-821b-4b52-b5db-8a677056efd4
# 1240        1240  e4173814-c658-4a0d-8cf4-39b16ded7714
# 1241        1241  e34a4d8e-1e2a-4703-ab34-1efb3938946a
#
#                         Name  Rate  Count of Rates    deliveryTime City Name  \
# 0          رستوران نیدا لانژ  4.13            16.0  20 تا 40 دقیقه     تهران
# 1          فست فود تی تی هات  3.77            78.0  40 تا 55 دقیقه     تهران
# ...

# %%
from sklearn.preprocessing import LabelEncoder
#
# Instantiate LabelEncoder
#
le = LabelEncoder()
#
# Encode single column status
#
df1.Restaurant_Id = le.fit_transform(df1.Name)
#
# Print df.head for checking the transformation
#
df1.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:5516: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#    Unnamed: 0  Restaurant_Id                    Name  Rate  Count of Rates  \
# 0           0            483       رستوران نیدا لانژ  4.13            16.0
# 1           1            681       فست فود تی تی هات  3.77            78.0
# 2           2            861        فست فود چیزی لاو  4.00            34.0
# 3           3            340  رستوران بلو لایف تهران  0.00             0.0
# 4           4            462      رستوران مطبخ شمرون  3.63            19.0
#
#      deliveryTime City Name  \
# 0  20 تا 40 دقیقه     تهران
# 1  40 تا 55 دقیقه     تهران
# 2  30 تا 45 دقیقه     تهران
# ...

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Restaurant_Id', 'Name', 'Rate', 'Count of Rates',
#        'deliveryTime', 'City Name', 'Address', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
#
# Instantiate LabelEncoder
#
le = LabelEncoder()
#
# Encode single column status
#
df1['Unnamed: 0'] = le.fit_transform(df1['City Name'])
#
# Print df.head for checking the transformation
#
df1.head()
# Out:
# <ipython-input-6-853cf4c10992>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Unnamed: 0'] = le.fit_transform(df1['City Name'])
#    Unnamed: 0  Restaurant_Id                    Name  Rate  Count of Rates  \
# 0           3            483       رستوران نیدا لانژ  4.13            16.0
# 1           3            681       فست فود تی تی هات  3.77            78.0
# 2           3            861        فست فود چیزی لاو  4.00            34.0
# 3           3            340  رستوران بلو لایف تهران  0.00             0.0
# 4           3            462      رستوران مطبخ شمرون  3.63            19.0
#
#      deliveryTime City Name  \
# 0  20 تا 40 دقیقه     تهران
# 1  40 تا 55 دقیقه     تهران
# 2  30 تا 45 دقیقه     تهران
# ...

# %%
df1.rename(columns = {'Unnamed: 0':'city_id'}, inplace = True)
df1
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#       city_id  Restaurant_Id                    Name  Rate  Count of Rates  \
# 0           3            483       رستوران نیدا لانژ  4.13            16.0
# 1           3            681       فست فود تی تی هات  3.77            78.0
# 2           3            861        فست فود چیزی لاو  4.00            34.0
# 3           3            340  رستوران بلو لایف تهران  0.00             0.0
# 4           3            462      رستوران مطبخ شمرون  3.63            19.0
# ...       ...            ...                     ...   ...             ...
# 1237        0            333         رستوران بانی چو  0.00             0.0
# ...

# %%
df2
# Out:
#        Unnamed: 0                    Name   City      area
# 0               0          فست فود صاب وی    کرج       110
# 1               1                    خروس  تهران       110
# 2               2  آبمیوه و بستنی تو دلیا    کرج       110
# 3               3            رستوران بوکا  تهران  آجودانیه
# 4               4           رستوران آواچی  تهران  آجودانیه
# ...           ...                     ...    ...       ...
# 63782       63782              پیتزا سنگی   اراک  کوی کوثر
# 63783       63783         رستوران بانی چو   اراک  کوی کوثر
# 63784       63784      کافه رستوران اسکای   اراک  کوی کوثر
# 63785       63785        تهیه غذای منظریه   اراک  کوی کوثر
# 63786       63786         تهیه غذای غذاچی   اراک  کوی کوثر
#
# [63787 rows x 4 columns]

# %%
df2=df2.drop("Unnamed: 0", axis='columns')
df2
# Out:
#                          Name   City      area
# 0              فست فود صاب وی    کرج       110
# 1                        خروس  تهران       110
# 2      آبمیوه و بستنی تو دلیا    کرج       110
# 3                رستوران بوکا  تهران  آجودانیه
# 4               رستوران آواچی  تهران  آجودانیه
# ...                       ...    ...       ...
# 63782              پیتزا سنگی   اراک  کوی کوثر
# 63783         رستوران بانی چو   اراک  کوی کوثر
# 63784      کافه رستوران اسکای   اراک  کوی کوثر
# 63785        تهیه غذای منظریه   اراک  کوی کوثر
# 63786         تهیه غذای غذاچی   اراک  کوی کوثر
#
# [63787 rows x 3 columns]

# %%
df1.columns
# Out:
# Index(['city_id', 'Restaurant_Id', 'Name', 'Rate', 'Count of Rates',
#        'deliveryTime', 'City Name', 'Address', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Name', 'City', 'area'], dtype='object')

# %%
df2.rename(columns = {'City':'City Name'}, inplace = True)
df2
# Out:
#                          Name City Name      area
# 0              فست فود صاب وی       کرج       110
# 1                        خروس     تهران       110
# 2      آبمیوه و بستنی تو دلیا       کرج       110
# 3                رستوران بوکا     تهران  آجودانیه
# 4               رستوران آواچی     تهران  آجودانیه
# ...                       ...       ...       ...
# 63782              پیتزا سنگی      اراک  کوی کوثر
# 63783         رستوران بانی چو      اراک  کوی کوثر
# 63784      کافه رستوران اسکای      اراک  کوی کوثر
# 63785        تهیه غذای منظریه      اراک  کوی کوثر
# 63786         تهیه غذای غذاچی      اراک  کوی کوثر
#
# [63787 rows x 3 columns]

# %%
df11 = pd.merge(df1, df2, on=['Name','City Name'], how='left')
df11
# Out:
#        city_id  Restaurant_Id                  Name  Rate  Count of Rates  \
# 0            3            483     رستوران نیدا لانژ  4.13            16.0
# 1            3            483     رستوران نیدا لانژ  4.13            16.0
# 2            3            483     رستوران نیدا لانژ  4.13            16.0
# 3            3            483     رستوران نیدا لانژ  4.13            16.0
# 4            3            483     رستوران نیدا لانژ  4.13            16.0
# ...        ...            ...                   ...   ...             ...
# 62604        0            234       تهیه غذای غذاچی  0.00             0.0
# 62605        0            234       تهیه غذای غذاچی  0.00             0.0
# 62606        0            234       تهیه غذای غذاچی  0.00             0.0
# 62607        0            234       تهیه غذای غذاچی  0.00             0.0
# 62608        0           1020  کافه رستوران ماتادور  0.00             0.0
#
#          deliveryTime City Name  \
# 0      20 تا 40 دقیقه     تهران
# ...

# %%
df11=df11.drop_duplicates(subset=['Name'])
df11
# Out:
#        city_id  Restaurant_Id                    Name  Rate  Count of Rates  \
# 0            3            483       رستوران نیدا لانژ  4.13            16.0
# 96           3            681       فست فود تی تی هات  3.77            78.0
# 126          3            861        فست فود چیزی لاو  4.00            34.0
# 209          3            340  رستوران بلو لایف تهران  0.00             0.0
# 254          3            462      رستوران مطبخ شمرون  3.63            19.0
# ...        ...            ...                     ...   ...             ...
# 62221        0            333         رستوران بانی چو  0.00             0.0
# 62327        0            527           رستوران ژیوان  0.00             0.0
# 62434        0            931                پیتزا تک  0.00             0.0
# 62492        0            234         تهیه غذای غذاچی  0.00             0.0
# 62608        0           1020    کافه رستوران ماتادور  0.00             0.0
#
#          deliveryTime City Name  \
# ...

# %%
df11.to_csv('se.csv')

# %%
df3
# Out:
#        Unnamed: 0                                    Id                  Name  \
# 0               0  822aec45-fcb3-47df-bab7-84a192e25b9d     فست فود تی تی هات
# 1               1  822aec45-fcb3-47df-bab7-84a192e25b9d     فست فود تی تی هات
# 2               2  822aec45-fcb3-47df-bab7-84a192e25b9d     فست فود تی تی هات
# 3               3  822aec45-fcb3-47df-bab7-84a192e25b9d     فست فود تی تی هات
# 4               4  822aec45-fcb3-47df-bab7-84a192e25b9d     فست فود تی تی هات
# ...           ...                                   ...                   ...
# 66050       66050  e34a4d8e-1e2a-4703-ab34-1efb3938946a  کافه رستوران ماتادور
# 66051       66051  e34a4d8e-1e2a-4703-ab34-1efb3938946a  کافه رستوران ماتادور
# 66052       66052  e34a4d8e-1e2a-4703-ab34-1efb3938946a  کافه رستوران ماتادور
# 66053       66053  e34a4d8e-1e2a-4703-ab34-1efb3938946a  کافه رستوران ماتادور
# 66054       66054  e34a4d8e-1e2a-4703-ab34-1efb3938946a  کافه رستوران ماتادور
#
# ...

# %%
df12 = pd.merge(df11, df3, on=['Name','City Name'], how='left')
df12
# Out:
#        city_id  Restaurant_Id                  Name  Rate  Count of Rates  \
# 0            3            483     رستوران نیدا لانژ  4.13            16.0
# 1            3            681     فست فود تی تی هات  3.77            78.0
# 2            3            681     فست فود تی تی هات  3.77            78.0
# 3            3            681     فست فود تی تی هات  3.77            78.0
# 4            3            681     فست فود تی تی هات  3.77            78.0
# ...        ...            ...                   ...   ...             ...
# 64941        0           1020  کافه رستوران ماتادور  0.00             0.0
# 64942        0           1020  کافه رستوران ماتادور  0.00             0.0
# 64943        0           1020  کافه رستوران ماتادور  0.00             0.0
# 64944        0           1020  کافه رستوران ماتادور  0.00             0.0
# 64945        0           1020  کافه رستوران ماتادور  0.00             0.0
#
#          deliveryTime City Name  \
# 0      20 تا 40 دقیقه     تهران
# ...

# %%
df12.columns
# Out:
# Index(['city_id', 'Restaurant_Id', 'Name', 'Rate', 'Count of Rates',
#        'deliveryTime', 'City Name', 'Address', 'Latitude', 'Longitude', 'area',
#        'Unnamed: 0', 'Id', 'Food_Category', 'Title', 'Ingredient', 'Price',
#        'Discount(%)', 'Food Tag', 'Sale On Ramadan', 'Sale On Breakfast',
#        'Sale On Noon', 'Sale On Night', 'Delino Recommendation'],
#       dtype='object')

# %%
df13=df12[['Restaurant_Id','Food_Category', 'Title', 'Ingredient', 'Price',
       'Discount(%)', 'Food Tag', 'Sale On Ramadan', 'Sale On Breakfast',
       'Sale On Noon', 'Sale On Night', 'Delino Recommendation']]
df13
# Out:
#        Restaurant_Id         Food_Category              Title  \
# 0                483                   NaN                NaN
# 1                681  پــیـتــزا یکـنفـره    پیتزا ویژه تی تی
# 2                681  پــیـتــزا یکـنفـره       پیتزا رست بیف
# 3                681  پــیـتــزا یکـنفـره   پیتزا قارچ و گوشت
# 4                681  پــیـتــزا یکـنفـره              پپرونی
# ...              ...                   ...                ...
# 64941           1020               نوشیدنی         دلستر لیمو
# 64942           1020               نوشیدنی          دلستر هلو
# 64943           1020               نوشیدنی      دلستر استوایی
# 64944           1020               نوشیدنی    لیموناد ماتادور
# 64945           1020               نوشیدنی       دلستر کلاسیک
#
#                                         Ingredient     Price  Discount(%)  \
# 0                                              NaN       NaN          NaN
# ...

# %%
df14 = df13.dropna(subset=['Title'])
df14
# Out:
#        Restaurant_Id         Food_Category              Title  \
# 1                681  پــیـتــزا یکـنفـره    پیتزا ویژه تی تی
# 2                681  پــیـتــزا یکـنفـره       پیتزا رست بیف
# 3                681  پــیـتــزا یکـنفـره   پیتزا قارچ و گوشت
# 4                681  پــیـتــزا یکـنفـره              پپرونی
# 5                681  پــیـتــزا یکـنفـره     پیتزا قارچ ومرغ
# ...              ...                   ...                ...
# 64941           1020               نوشیدنی         دلستر لیمو
# 64942           1020               نوشیدنی          دلستر هلو
# 64943           1020               نوشیدنی      دلستر استوایی
# 64944           1020               نوشیدنی    لیموناد ماتادور
# 64945           1020               نوشیدنی       دلستر کلاسیک
#
#                                         Ingredient     Price  Discount(%)  \
# 1      رست بیف، فیله مرغ، قارچ، فلفل دلمه ای، پنیر  129000.0          0.0
# ...

# %%
df14.to_csv('foods.csv')

# %%
df11
# Out:
#        city_id  Restaurant_Id                    Name  Rate  Count of Rates  \
# 0            3            483       رستوران نیدا لانژ  4.13            16.0
# 96           3            681       فست فود تی تی هات  3.77            78.0
# 126          3            861        فست فود چیزی لاو  4.00            34.0
# 209          3            340  رستوران بلو لایف تهران  0.00             0.0
# 254          3            462      رستوران مطبخ شمرون  3.63            19.0
# ...        ...            ...                     ...   ...             ...
# 62221        0            333         رستوران بانی چو  0.00             0.0
# 62327        0            527           رستوران ژیوان  0.00             0.0
# 62434        0            931                پیتزا تک  0.00             0.0
# 62492        0            234         تهیه غذای غذاچی  0.00             0.0
# 62608        0           1020    کافه رستوران ماتادور  0.00             0.0
#
#          deliveryTime City Name  \
# ...

# %%
df5=df11[['city_id','City Name']]
df5
# Out:
#        city_id City Name
# 0            3     تهران
# 96           3     تهران
# 126          3     تهران
# 209          3     تهران
# 254          3     تهران
# ...        ...       ...
# 62221        0      اراک
# 62327        0      اراک
# 62434        0      اراک
# 62492        0      اراک
# 62608        0      اراک
#
# [1164 rows x 2 columns]

# %%
df6=df5.drop_duplicates()
df6
# Out:
#        city_id   City Name
# 0            3       تهران
# 34613        5          قم
# 41135        2    بندرعباس
# 41524        7         کرج
# 44053        4         رشت
# 44486        8       گرگان
# 53385        6       همدان
# 53530       10         یزد
# 57053        1      ارومیه
# 60827        9  گنبد کاووس
# 61278        0        اراک

# %%
df6.to_csv('cities.csv')

# %%
df11.columns
# Out:
# Index(['city_id', 'Restaurant_Id', 'Name', 'Rate', 'Count of Rates',
#        'deliveryTime', 'City Name', 'Address', 'Latitude', 'Longitude',
#        'area'],
#       dtype='object')

# %%
df7=df11[['city_id','Address', 'Latitude', 'Longitude',
       'area']]
df7
# Out:
#        city_id                                            Address   Latitude  \
# 0            3  نیاوران، خیابان شهید مقدسی (مژده) خیابان میری،...  35.816131
# 96           3  پونک، بین خیابان سردار جنگل و عدل، خیابان اردی...  35.765042
# 126          3  پونک، بلوار همیلا، خیابان اورک، بین کوچه 8 و 1...  35.760783
# 209          3       دزاشیب، خیابان کریمی، کوچه حسین فلاح، پلاک 9  35.805820
# 254          3  بلوار اندرزگو، خیابان سلیمی شمالی، خیابان اشکس...  35.800725
# ...        ...                                                ...        ...
# 62221        0             اراک، خیابان شریعتی، نبش کوچه بانک ملت  34.077674
# 62327        0               اراک، خیابان شریعتی، نبش کوچه پامچال  34.076947
# 62434        0  اراک، سه راه ابوذر، خیابان ابوذر، روبروی نانوا...  34.095735
# 62492        0            اراک-میدان امام حسین-جنب مسجد امام حسین  34.120778
# 62608        0  اراک، خیابان شیرودی(خرم)، نبش کوچه مبارزان، جن...  34.076281
#
#        Longitude            area
# ...

# %%
df7.to_csv('locations.csv')

# %%
df11.columns
# Out:
# Index(['city_id', 'Restaurant_Id', 'Name', 'Rate', 'Count of Rates',
#        'deliveryTime', 'City Name', 'Address', 'Latitude', 'Longitude',
#        'area'],
#       dtype='object')

# %%
df8=df11[['Restaurant_Id', 'Name', 'Rate', 'Count of Rates',
       'deliveryTime']]
df8
# Out:
#        Restaurant_Id                    Name  Rate  Count of Rates  \
# 0                483       رستوران نیدا لانژ  4.13            16.0
# 96               681       فست فود تی تی هات  3.77            78.0
# 126              861        فست فود چیزی لاو  4.00            34.0
# 209              340  رستوران بلو لایف تهران  0.00             0.0
# 254              462      رستوران مطبخ شمرون  3.63            19.0
# ...              ...                     ...   ...             ...
# 62221            333         رستوران بانی چو  0.00             0.0
# 62327            527           رستوران ژیوان  0.00             0.0
# 62434            931                پیتزا تک  0.00             0.0
# 62492            234         تهیه غذای غذاچی  0.00             0.0
# 62608           1020    کافه رستوران ماتادور  0.00             0.0
#
#          deliveryTime
# 0      20 تا 40 دقیقه
# 96     40 تا 55 دقیقه
# 126    30 تا 45 دقیقه
# 209    25 تا 45 دقیقه
# 254    25 تا 45 دقیقه
# ...

# %%
df8.to_csv('restaurants.csv')

# %%
df1 = pd.read_csv('/content/cities.csv')
df2 = pd.read_csv('/content/locations.csv')
df3 = pd.read_csv('/content/restaurants.csv')
df4 = pd.read_csv('/content/foods.csv')

# %%
df1
# Out:
#     Unnamed: 0  city_id   City Name
# 0            0        3       تهران
# 1        34613        5          قم
# 2        41135        2    بندرعباس
# 3        41524        7         کرج
# 4        44053        4         رشت
# 5        44486        8       گرگان
# 6        53385        6       همدان
# 7        53530       10         یزد
# 8        57053        1      ارومیه
# 9        60827        9  گنبد کاووس
# 10       61278        0        اراک

# %%
df2
# Out:
#       Unnamed: 0  city_id                                            Address  \
# 0              0        3  نیاوران، خیابان شهید مقدسی (مژده) خیابان میری،...
# 1             96        3  پونک، بین خیابان سردار جنگل و عدل، خیابان اردی...
# 2            126        3  پونک، بلوار همیلا، خیابان اورک، بین کوچه 8 و 1...
# 3            209        3       دزاشیب، خیابان کریمی، کوچه حسین فلاح، پلاک 9
# 4            254        3  بلوار اندرزگو، خیابان سلیمی شمالی، خیابان اشکس...
# ...          ...      ...                                                ...
# 1159       62221        0             اراک، خیابان شریعتی، نبش کوچه بانک ملت
# 1160       62327        0               اراک، خیابان شریعتی، نبش کوچه پامچال
# 1161       62434        0  اراک، سه راه ابوذر، خیابان ابوذر، روبروی نانوا...
# 1162       62492        0            اراک-میدان امام حسین-جنب مسجد امام حسین
# 1163       62608        0  اراک، خیابان شیرودی(خرم)، نبش کوچه مبارزان، جن...
#
#        Latitude  Longitude            area
# ...

# %%
df2=df2.drop("Unnamed: 0", axis='columns')
df2
# Out:
#       city_id                                            Address   Latitude  \
# 0           3  نیاوران، خیابان شهید مقدسی (مژده) خیابان میری،...  35.816131
# 1           3  پونک، بین خیابان سردار جنگل و عدل، خیابان اردی...  35.765042
# 2           3  پونک، بلوار همیلا، خیابان اورک، بین کوچه 8 و 1...  35.760783
# 3           3       دزاشیب، خیابان کریمی، کوچه حسین فلاح، پلاک 9  35.805820
# 4           3  بلوار اندرزگو، خیابان سلیمی شمالی، خیابان اشکس...  35.800725
# ...       ...                                                ...        ...
# 1159        0             اراک، خیابان شریعتی، نبش کوچه بانک ملت  34.077674
# 1160        0               اراک، خیابان شریعتی، نبش کوچه پامچال  34.076947
# 1161        0  اراک، سه راه ابوذر، خیابان ابوذر، روبروی نانوا...  34.095735
# 1162        0            اراک-میدان امام حسین-جنب مسجد امام حسین  34.120778
# 1163        0  اراک، خیابان شیرودی(خرم)، نبش کوچه مبارزان، جن...  34.076281
#
#       Longitude            area
# ...

# %%
df2.index += 1
df2
# Out:
#       city_id                                            Address   Latitude  \
# 1           3  نیاوران، خیابان شهید مقدسی (مژده) خیابان میری،...  35.816131
# 2           3  پونک، بین خیابان سردار جنگل و عدل، خیابان اردی...  35.765042
# 3           3  پونک، بلوار همیلا، خیابان اورک، بین کوچه 8 و 1...  35.760783
# 4           3       دزاشیب، خیابان کریمی، کوچه حسین فلاح، پلاک 9  35.805820
# 5           3  بلوار اندرزگو، خیابان سلیمی شمالی، خیابان اشکس...  35.800725
# ...       ...                                                ...        ...
# 1160        0             اراک، خیابان شریعتی، نبش کوچه بانک ملت  34.077674
# 1161        0               اراک، خیابان شریعتی، نبش کوچه پامچال  34.076947
# 1162        0  اراک، سه راه ابوذر، خیابان ابوذر، روبروی نانوا...  34.095735
# 1163        0            اراک-میدان امام حسین-جنب مسجد امام حسین  34.120778
# 1164        0  اراک، خیابان شیرودی(خرم)، نبش کوچه مبارزان، جن...  34.076281
#
#       Longitude            area
# ...

# %%
df2.to_csv('location2.csv', index_label='id')

# %%
df3
# Out:
#       Unnamed: 0  Restaurant_Id                    Name  Rate  Count of Rates  \
# 0              0            483       رستوران نیدا لانژ  4.13            16.0
# 1             96            681       فست فود تی تی هات  3.77            78.0
# 2            126            861        فست فود چیزی لاو  4.00            34.0
# 3            209            340  رستوران بلو لایف تهران  0.00             0.0
# 4            254            462      رستوران مطبخ شمرون  3.63            19.0
# ...          ...            ...                     ...   ...             ...
# 1159       62221            333         رستوران بانی چو  0.00             0.0
# 1160       62327            527           رستوران ژیوان  0.00             0.0
# 1161       62434            931                پیتزا تک  0.00             0.0
# 1162       62492            234         تهیه غذای غذاچی  0.00             0.0
# 1163       62608           1020    کافه رستوران ماتادور  0.00             0.0
#
#         deliveryTime
# ...

# %%
df3=df3.drop("Unnamed: 0", axis='columns')
df3
# Out:
#       Restaurant_Id                    Name  Rate  Count of Rates  \
# 0               483       رستوران نیدا لانژ  4.13            16.0
# 1               681       فست فود تی تی هات  3.77            78.0
# 2               861        فست فود چیزی لاو  4.00            34.0
# 3               340  رستوران بلو لایف تهران  0.00             0.0
# 4               462      رستوران مطبخ شمرون  3.63            19.0
# ...             ...                     ...   ...             ...
# 1159            333         رستوران بانی چو  0.00             0.0
# 1160            527           رستوران ژیوان  0.00             0.0
# 1161            931                پیتزا تک  0.00             0.0
# 1162            234         تهیه غذای غذاچی  0.00             0.0
# 1163           1020    کافه رستوران ماتادور  0.00             0.0
#
#         deliveryTime
# 0     20 تا 40 دقیقه
# 1     40 تا 55 دقیقه
# 2     30 تا 45 دقیقه
# 3     25 تا 45 دقیقه
# 4     25 تا 45 دقیقه
# ...              ...
# ...

# %%
df3.index += 1
df3
# Out:
#       Restaurant_Id                    Name  Rate  Count of Rates  \
# 1               483       رستوران نیدا لانژ  4.13            16.0
# 2               681       فست فود تی تی هات  3.77            78.0
# 3               861        فست فود چیزی لاو  4.00            34.0
# 4               340  رستوران بلو لایف تهران  0.00             0.0
# 5               462      رستوران مطبخ شمرون  3.63            19.0
# ...             ...                     ...   ...             ...
# 1160            333         رستوران بانی چو  0.00             0.0
# 1161            527           رستوران ژیوان  0.00             0.0
# 1162            931                پیتزا تک  0.00             0.0
# 1163            234         تهیه غذای غذاچی  0.00             0.0
# 1164           1020    کافه رستوران ماتادور  0.00             0.0
#
#         deliveryTime
# 1     20 تا 40 دقیقه
# 2     40 تا 55 دقیقه
# 3     30 تا 45 دقیقه
# 4     25 تا 45 دقیقه
# 5     25 تا 45 دقیقه
# ...              ...
# ...

# %%
df3.to_csv('restaurant2.csv', index_label='location_id')

# %%
df4
# Out:
#        Unnamed: 0  Restaurant_Id         Food_Category              Title  \
# 0               1            681  پــیـتــزا یکـنفـره    پیتزا ویژه تی تی
# 1               2            681  پــیـتــزا یکـنفـره       پیتزا رست بیف
# 2               3            681  پــیـتــزا یکـنفـره   پیتزا قارچ و گوشت
# 3               4            681  پــیـتــزا یکـنفـره              پپرونی
# 4               5            681  پــیـتــزا یکـنفـره     پیتزا قارچ ومرغ
# ...           ...            ...                   ...                ...
# 64900       64941           1020               نوشیدنی         دلستر لیمو
# 64901       64942           1020               نوشیدنی          دلستر هلو
# 64902       64943           1020               نوشیدنی      دلستر استوایی
# 64903       64944           1020               نوشیدنی    لیموناد ماتادور
# 64904       64945           1020               نوشیدنی       دلستر کلاسیک
#
#                                         Ingredient     Price  Discount(%)  \
# ...

# %%
df4=df4.drop("Unnamed: 0", axis='columns')
df4
# Out:
#        Restaurant_Id         Food_Category              Title  \
# 0                681  پــیـتــزا یکـنفـره    پیتزا ویژه تی تی
# 1                681  پــیـتــزا یکـنفـره       پیتزا رست بیف
# 2                681  پــیـتــزا یکـنفـره   پیتزا قارچ و گوشت
# 3                681  پــیـتــزا یکـنفـره              پپرونی
# 4                681  پــیـتــزا یکـنفـره     پیتزا قارچ ومرغ
# ...              ...                   ...                ...
# 64900           1020               نوشیدنی         دلستر لیمو
# 64901           1020               نوشیدنی          دلستر هلو
# 64902           1020               نوشیدنی      دلستر استوایی
# 64903           1020               نوشیدنی    لیموناد ماتادور
# 64904           1020               نوشیدنی       دلستر کلاسیک
#
#                                         Ingredient     Price  Discount(%)  \
# 0      رست بیف، فیله مرغ، قارچ، فلفل دلمه ای، پنیر  129000.0          0.0
# ...

# %%
df4.index += 1
df4
# Out:
#        Restaurant_Id         Food_Category              Title  \
# 1                681  پــیـتــزا یکـنفـره    پیتزا ویژه تی تی
# 2                681  پــیـتــزا یکـنفـره       پیتزا رست بیف
# 3                681  پــیـتــزا یکـنفـره   پیتزا قارچ و گوشت
# 4                681  پــیـتــزا یکـنفـره              پپرونی
# 5                681  پــیـتــزا یکـنفـره     پیتزا قارچ ومرغ
# ...              ...                   ...                ...
# 64901           1020               نوشیدنی         دلستر لیمو
# 64902           1020               نوشیدنی          دلستر هلو
# 64903           1020               نوشیدنی      دلستر استوایی
# 64904           1020               نوشیدنی    لیموناد ماتادور
# 64905           1020               نوشیدنی       دلستر کلاسیک
#
#                                         Ingredient     Price  Discount(%)  \
# 1      رست بیف، فیله مرغ، قارچ، فلفل دلمه ای، پنیر  129000.0          0.0
# ...

# %%
df4.to_csv('foods2.csv', index_label='id')
